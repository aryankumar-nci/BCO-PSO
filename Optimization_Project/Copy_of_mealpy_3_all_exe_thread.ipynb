# %%
pip install mealpy mealpy==3.0.1
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: mealpy in c:\users\asus\appdata\roaming\python\python312\site-packages (3.0.1)
# Requirement already satisfied: numpy>=1.17.5 in c:\users\asus\appdata\roaming\python\python312\site-packages (from mealpy) (2.2.6)
# Requirement already satisfied: matplotlib>=3.3.0 in c:\users\asus\appdata\roaming\python\python312\site-packages (from mealpy) (3.10.1)
# Requirement already satisfied: scipy>=1.7.1 in c:\users\asus\appdata\roaming\python\python312\site-packages (from mealpy) (1.15.3)
# Requirement already satisfied: pandas>=1.2.0 in c:\users\asus\appdata\roaming\python\python312\site-packages (from mealpy) (2.2.3)
# Requirement already satisfied: opfunu>=1.0.0 in c:\users\asus\appdata\roaming\python\python312\site-packages (from mealpy) (1.0.1)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\asus\appdata\roaming\python\python312\site-packages (from matplotlib>=3.3.0->mealpy) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\asus\appdata\roaming\python\python312\site-packages (from matplotlib>=3.3.0->mealpy) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\asus\appdata\roaming\python\python312\site-packages (from matplotlib>=3.3.0->mealpy) (4.56.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\asus\appdata\roaming\python\python312\site-packages (from matplotlib>=3.3.0->mealpy) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in c:\users\asus\appdata\roaming\python\python312\site-packages (from matplotlib>=3.3.0->mealpy) (24.2)
# Requirement already satisfied: pillow>=8 in c:\users\asus\appdata\roaming\python\python312\site-packages (from matplotlib>=3.3.0->mealpy) (11.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\asus\appdata\roaming\python\python312\site-packages (from matplotlib>=3.3.0->mealpy) (3.2.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\asus\appdata\roaming\python\python312\site-packages (from matplotlib>=3.3.0->mealpy) (2.9.0.post0)
# Requirement already satisfied: requests>=2.27.0 in c:\users\asus\appdata\roaming\python\python312\site-packages (from opfunu>=1.0.0->mealpy) (2.32.3)
# Requirement already satisfied: pytz>=2020.1 in c:\users\asus\appdata\roaming\python\python312\site-packages (from pandas>=1.2.0->mealpy) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\asus\appdata\roaming\python\python312\site-packages (from pandas>=1.2.0->mealpy) (2024.2)
# Requirement already satisfied: six>=1.5 in c:\users\asus\appdata\roaming\python\python312\site-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->mealpy) (1.17.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\asus\appdata\roaming\python\python312\site-packages (from requests>=2.27.0->opfunu>=1.0.0->mealpy) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\asus\appdata\roaming\python\python312\site-packages (from requests>=2.27.0->opfunu>=1.0.0->mealpy) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\asus\appdata\roaming\python\python312\site-packages (from requests>=2.27.0->opfunu>=1.0.0->mealpy) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\asus\appdata\roaming\python\python312\site-packages (from requests>=2.27.0->opfunu>=1.0.0->mealpy) (2025.1.31)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.0.1 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from mealpy import FloatVar, ABC
from mealpy import *
import json
import time
import os

# %%
vmcount=1
size=1
tcount=1
task=1
vm=1

data = {}

# %%
f = open('data_10000_5'+'.json')
data = json.load(f)
vmcount1= data['vmcount'][0]
vmcount=vmcount1
size=data['tcount'][0]

# %%
def Fun1(solution):
  list1 = [0] * data['vmcount'][0]
  val = 0.0
  #print(solution)
  #print(int(round(solution[0])))
  for i in range(solution.size):
    solution[i]=round(solution[i])
    if(round(solution[i])!=0.0):
      list1[int(abs(round(solution[i],0)))-1]=list1[int(abs(round(solution[i],0)))-1] + data['task'][0]/data['VM'][int(abs(round(solution[i],0)))-1]
    else:
      list1[int(abs(round(solution[i])))]=list1[int(abs(round(solution[i],0)))] + data['task'][0]/data['VM'][int(abs(round(solution[i])))]

  print(max(list1))
  l=max(list1)
  uitli=[x/l for x in list1]
  import numpy as np
  print(np.mean(uitli)*100)

# %%
def Fun(solution):
  list1 = [0] * data['vmcount'][0]
  val = 0.0
  #print(solution)
  #print(int(round(solution[0])))
  for i in range(solution.size):
    solution[i]=round(solution[i])
    if(round(solution[i])!=0.0):
      list1[int(round(solution[i]))-1]=list1[int(round(solution[i]))-1] + data['task'][0]/data['VM'][int(round(solution[i]))-1]
    else:
      list1[int(round(solution[i]))]=list1[int(round(solution[i]))] + data['task'][0]/data['VM'][int(round(solution[i]))]
  #print(solution)
  return max(list1)

start_time = time.time()

# %%
def optimize(json_file,algo,size1,vmcount1):
  problem_dict = {
    "bounds": FloatVar(lb=[0 for i in range(size1)] , ub=[vmcount1-1 for i in range(size1)], name="delta"),
    "minmax": "min",
    "obj_func": Fun
  }
  if(algo=="BBO"):
    model = BBO.OriginalBBO(epoch=10, pop_size=30, p_m=0.01, n_elites=2)
  if(algo=="PSO"):
    model = PSO.OriginalPSO(epoch=100, pop_size=50, c1=2.05, c2=2.5, w=0.4)
  if(algo=="PSO2"):
    model = PSO.LDW_PSO(epoch=100, pop_size=50, c1=2.05, c2=2.5, w_min=0.4, w_max=0.9)
  if(algo=="PSO3"):
    model = PSO.AIW_PSO(epoch=100, pop_size=50, c1=2.05, c2=2.5, alpha=0.4)
  if(algo=="PSO4"):
    model = PSO.P_PSO(epoch=100, pop_size=50)
  if(algo=="PSO5"):
    model = PSO.HPSO_TVAC(epoch=100, pop_size=50, ci=0.5, cf=0.1)
  if(algo=="PSO6"):
    model = PSO.C_PSO(epoch=100, pop_size=50, c1=2.05, c2=2.05, w_min=0.4, w_max=0.9)
  if(algo=="PSO7"):
    model = PSO.CL_PSO(epoch=100, pop_size=50, c_local=1.2, w_min=0.4, w_max=0.9, max_flag=7)
  if(algo=="GA"):
    model = GA.BaseGA(epoch=100, pop_size=50, pc=0.9, pm=0.05, selection="tournament", k_way=0.4, crossover="multi_points", mutation="swap")
  if(algo=="GA1"):
    model = GA.SingleGA(epoch=100, pop_size=50, pc=0.9, pm=0.8, selection="tournament", k_way=0.4, crossover="multi_points", mutation="swap")
  if(algo=="GA2"):
    model = GA.MultiGA(epoch=100, pop_size=50, pc=0.9, pm=0.8, selection="tournament", k_way=0.4, crossover="multi_points", mutation="swap")
  if(algo=="GA3"):
    model = GA.EliteSingleGA(epoch=100, pop_size=50, pc=0.95, pm=0.8, selection="roulette", crossover="uniform", mutation="swap", k_way=0.2, elite_best=0.1,
  te_worst=0.3, strategy=0)
  if(algo=="GA4"):
    model = GA.EliteMultiGA(epoch=100, pop_size=50, pc=0.95, pm=0.8, selection="roulette", crossover="uniform", mutation="swap", k_way=0.2, elite_best=0.1,elite_worst=0.3, strategy=0)
  if(algo=="ABC"):
    model = ABC.OriginalABC(epoch=1000, pop_size=50, n_limits=50)
  if(algo=="ACOR"):
    model = ACOR.OriginalACOR(epoch=1000, pop_size=50, sample_count=25, intent_factor=0.5, zeta=1.0)
  if(algo=="AGTO"):
    model = AGTO.OriginalAGTO(epoch=1000, pop_size=50, p1=0.03, p2=0.8, beta=3.0)
  if(algo=="AGTO1"):
    model = AGTO.MGTO(epoch=1000, pop_size=50, pp=0.03)
  if(algo=="ALO"):
    model = ALO.OriginalALO(epoch=100, pop_size=50)
  if(algo=="ALO1"):
    model = ALO.DevALO(epoch=100, pop_size=50)
  if(algo=="AO"):
    model = AO.OriginalAO(epoch=100, pop_size=50)
  if(algo=="ARO"):
    model = ARO.OriginalARO(epoch=100, pop_size=50)
  if(algo=="ARO1"):
    model = ARO.LARO(epoch=100, pop_size=50)
  if(algo=="ARO1"):
    model = ARO.IARO(epoch=100, pop_size=50)
  if(algo=="AVOA"):
    model = AVOA.OriginalAVOA(epoch=100, pop_size=50, p1=0.6, p2=0.4, p3=0.6, alpha=0.8, gama=2.5)
  if(algo=="BA"):
    model = BA.OriginalBA(epoch=100, pop_size=50, loudness=0.8, pulse_rate=0.95, pf_min=0.1, pf_max=10.0)
  if(algo=="BA1"):
    model = BA.AdaptiveBA(epoch=100, pop_size=50, loudness_min=1.0, loudness_max=2.0, pr_min=-2.5, pr_max=0.85, pf_min=0.1, pf_max=10.)
  if(algo=="BA2"):
    model = BA.DevBA(epoch=100, pop_size=50, pulse_rate=0.95, pf_min=0., pf_max=10.)
  if(algo=="BBO"):
    model = BBOA.OriginalBBOA(epoch=100, pop_size=50)
  if(algo=="BWO"):
    model = BMO.OriginalBMO(epoch=100, pop_size=50, pl=4)
  if(algo=="EOA"):
    model = EOA.OriginalEOA(epoch=100, pop_size=50, p_c=0.9, p_m=0.01, n_best=2, alpha=0.98, beta=0.9, gama=0.9)
  if(algo=="IWO"):
    model = IWO.OriginalIWO(epoch=100, pop_size=50, seed_min=3, seed_max=9, exponent=3, sigma_start=0.6, sigma_end=0.01)
  if(algo=="SBO"):
    model = SBO.DevSBO(epoch=100, pop_size=50, alpha=0.9, p_m=0.05, psw=0.02)
  if(algo=="SBO1"):
    model = SBO.OriginalSBO(epoch=100, pop_size=50, alpha=0.9, p_m=0.05, psw=0.02)
  if(algo=="SMA"):
    model = SMA.OriginalSMA(epoch=100, pop_size=50, p_t=0.03)
  if(algo=="SMA1"):
    model = SMA.DevSMA(epoch=100, pop_size=50, p_t=0.03)
  if(algo=="SOA"):
    model = SOA.OriginalSOA(epoch=100, pop_size=50, fc=2)
  if(algo=="SOA"):
    model = SOA.DevSOA(epoch=100, pop_size=50, fc=2)
  if(algo=="SOS"):
    model = SOS.OriginalSOS(epoch=100, pop_size=50)
  if(algo=="TPO"):
    model = TPO.DevTPO(epoch=100, pop_size=50, alpha=0.3, beta=50., theta=0.9)
  if(algo=="TSA"):
    model = TSA.OriginalTSA(epoch=100, pop_size=50)
  if(algo=="VCS"):
    model = VCS.OriginalVCS(epoch=100, pop_size=50, lamda=0.5, sigma=0.3)
  if(algo=="VCS"):
    model = VCS.DevVCS(epoch=100, pop_size=50, lamda=0.5, sigma=0.3)
  if(algo=="WHO"):
    model = WHO.OriginalWHO(epoch=100, pop_size=50, n_explore_step=3, n_exploit_step=3, eta=0.15, p_hi=0.9, local_alpha=0.9, local_beta=0.3, global_alpha=0.2,global_beta=0.8, delta_w=2.0, delta_c=2.0)
  if(algo=="AOA"):
    model = AOA.OriginalAOA(epoch=100, pop_size=50, alpha=5, miu=0.5, moa_min=0.2, moa_max=0.9)
  if(algo=="CEM"):
    model = CEM.OriginalCEM(epoch=100, pop_size=50, n_best=20, alpha=0.7)
  if(algo=="CGO"):
    model = CGO.OriginalCGO(epoch=100, pop_size=50)
  if(algo=="CircleSA"):
    model = CircleSA.OriginalCircleSA(epoch=100, pop_size=50, c_factor=0.8)
  if(algo=="GBO"):
    model = GBO.OriginalGBO(epoch=100, pop_size=50, pr=0.5, beta_min=0.2, beta_max=1.2)
  if(algo=="HC"):
    model = HC.OriginalHC(epoch=100, pop_size=50, neighbour_size=50)
  if(algo=="HC1"):
    model = HC.SwarmHC(epoch=100, pop_size=50, neighbour_size=10)
  if(algo=="INFO"):
    model = INFO.OriginalINFO(epoch=100, pop_size=50)
  if(algo=="PSS"):
    model = PSS.OriginalPSS(epoch=100, pop_size=50, acceptance_rate=0.8, sampling_method="LHS")
  if(algo=="RUN"):
    model = RUN.OriginalRUN(epoch=100, pop_size=50)
  if(algo=="SCA"):
    model = SCA.OriginalSCA(epoch=100, pop_size=50)
  if(algo=="SCA1"):
    model = SCA2.DevSCA(epoch=100, pop_size=50)
  if(algo=="SCA3"):
    model = SCA.QleSCA(epoch=100, pop_size=50, alpha=0.1, gama=0.9)
  if(algo=="SHIO"):
    model = SHIO.OriginalSHIO(epoch=100, pop_size=50)
  if(algo=="TS"):
    model = TS.OriginalTS(epoch=100, pop_size=50, tabu_size=5, neighbour_size=20, perturbation_scale=0.05)
  if(algo=="HS"):
    model = HS.OriginalHS(epoch=100, pop_size=50, c_r=0.95, pa_r=0.05)
  if(algo=="HS1"):
    model = HS.DevHS(epoch=100, pop_size=50, c_r=0.95, pa_r=0.05)
  if(algo=="AEO"):
    model = AEO.OriginalAEO(epoch=100, pop_size=50)
  if(algo=="AEO1"):
    model = AEO.EnhancedAEO(epoch=100, pop_size=50)
  if(algo=="AEO2"):
    model = AEO.ModifiedAEO(epoch=100, pop_size=50)
  if(algo=="AEO3"):
    model = AEO.ImprovedAEO(epoch=100, pop_size=50)
  if(algo=="AEO4"):
    model = AEO.AugmentedAEO(epoch=100, pop_size=50)
  if(algo=="GCO"):
    model = GCO.OriginalGCO(epoch=100, pop_size=50, cr=0.7, wf=1.25)
  if(algo=="GCO1"):
    model = GCO.DevGCO(epoch=100, pop_size=50, cr=0.7, wf=1.25)
  if(algo=="WCA"):
    model = WCA.OriginalWCA(epoch=100, pop_size=50, nsr=4, wc=2.0, dmax=1e-6)
  if(algo=="CRO"):
    model = CRO.OriginalCRO(epoch=100, pop_size=50, po=0.4, Fb=0.9, Fa=0.1, Fd=0.1, Pd=0.5, GCR=0.1, gamma_min=0.02, gamma_max=0.2, n_trials=5)
  if(algo=="CRO1"):
    model = CRO.OCRO(epoch=100, pop_size=50, po=0.4, Fb=0.9, Fa=0.1, Fd=0.1, Pd=0.5, GCR=0.1, gamma_min=0.02, gamma_max=0.2, n_trials=5, restart_count=50)
  if(algo=="DE"):
    model = DE.OriginalDE(epoch=100, pop_size=50, wf=0.7, cr=0.9, strategy=0)
  if(algo=="DE1"):
    model = DE.JADE(epoch=100, pop_size=50, miu_f=0.5, miu_cr=0.5, pt=0.1, ap=0.1)
  if(algo=="DE2"):
    model = DE.SADE(epoch=100, pop_size=50)
  if(algo=="DE3"):
    model = DE.SAP_DE(epoch=100, pop_size=50, branch="ABS")
  if(algo=="EP"):
    model = EP.OriginalEP(epoch=100, pop_size=50, bout_size=0.05)
  if(algo=="EP1"):
    model = EP.LevyEP(epoch=100, pop_size=50, bout_size=0.05)
  if(algo=="ES"):
    model = ES.OriginalES(epoch=100, pop_size=50, lamda=0.75)
  if(algo=="ES1"):
    model = ES.LevyES(epoch=100, pop_size=50, lamda=0.75)
  if(algo=="ES2"):
    model = ES.CMA_ES(epoch=100, pop_size=50)
  if(algo=="ES3"):
    model = ES.Simple_CMA_ES(epoch=100, pop_size=50)
  if(algo=="FPA"):
    model = FPA.OriginalFPA(epoch=100, pop_size=50, p_s=0.8, levy_multiplier=0.2)
  if(algo=="MA"):
    model = MA.OriginalMA(epoch=100, pop_size=50, pc=0.85, pm=0.15, p_local=0.5, max_local_gens=10, bits_per_param=4)
  if(algo=="SHADE"):
    model = SHADE.OriginalSHADE(epoch=100, pop_size=50, miu_f=0.5, miu_cr=0.5)
  if(algo=="SHADE2"):
    model = SHADE.L_SHADE(epoch=100, pop_size=50, miu_f=0.5, miu_cr=0.5)
  if(algo=="BRO"):
    model = BRO.OriginalBRO(epoch=100, pop_size=50, threshold=3)
  if(algo=="BRO1"):
    model = BRO.DevBRO(epoch=100, pop_size=50, threshold=3)
  if(algo=="BSO"):
    model = BSO.OriginalBSO(epoch=100, pop_size=50, m_clusters=5, p1=0.2, p2=0.8, p3=0.4, p4=0.5, slope=20)
  if(algo=="BSO1"):
    model = BSO.ImprovedBSO(epoch=100, pop_size=50, m_clusters=5, p1=0.25, p2=0.5, p3=0.75, p4=0.6)
  if(algo=="CA"):
    model = CA.OriginalCA(epoch=100, pop_size=50, accepted_rate=0.15)
  if(algo=="CHIO"):
    model = CHIO.OriginalCHIO(epoch=100, pop_size=50, brr=0.15, max_age=10)
  if(algo=="CHIO1"):
    model = CHIO.DevCHIO(epoch=100, pop_size=50, brr=0.15, max_age=10)
  if(algo=="FBIO"):
    model = FBIO.OriginalFBIO(epoch=100, pop_size=50)
  if(algo=="FBIO1"):
    model = FBIO.DevFBIO(epoch=100, pop_size=50)
  if(algo=="GSKA"):
    model = GSKA.OriginalGSKA(epoch=100, pop_size=50, pb=0.1, kf=0.5, kr=0.9, kg=5)
  if(algo=="GSKA1"):
    model = GSKA.DevGSKA(epoch=100, pop_size=50, pb=0.1, kr=0.9)
  if(algo=="HBO"):
    model = HBO.OriginalHBO(epoch=100, pop_size=50, degree=3)
  if(algo=="HCO"):
    model = HCO.OriginalHCO(epoch=100, pop_size=50, wfp=0.65, wfv=0.05, c1=1.4, c2=1.4)
  if(algo=="ICA"):
    model = ICA.OriginalICA(epoch=100, pop_size=50, empire_count=5, assimilation_coeff=1.5, revolution_prob=0.05, revolution_rate=0.1, revolution_step_size=0.1,zeta=0.1)
  if(algo=="LCO"):
    model = LCO.OriginalLCO(epoch=100, pop_size=50, r1=2.35)
  if(algo=="LCO1"):
    model = LCO.ImprovedLCO(epoch=100, pop_size=50)
  if(algo=="LCO2"):
    model = LCO.DevLCO(epoch=100, pop_size=50, r1=2.35)
  if(algo=="WarSO"):
    model = WarSO.OriginalWarSO(epoch=100, pop_size=50, rr=0.1)
  if(algo=="TOA"):
    model = TOA.OriginalTOA(epoch=100, pop_size=50)
  if(algo=="TLO"):
    model = TLO.OriginalTLO(epoch=100, pop_size=50)
  if(algo=="TLO1"):
    model = TLO.ImprovedTLO(epoch=100, pop_size=50, n_teachers=5)
  if(algo=="TLO2"):
    model = TLO.DevTLO(epoch=100, pop_size=50)
  if(algo=="SSDO"):
    model = SSDO.OriginalSSDO(epoch=100, pop_size=50)
  if(algo=="SPBO"):
    model = SPBO.OriginalSPBO(epoch=100, pop_size=50)
  if(algo=="SPBO1"):
    model = SPBO.DevSPBO(epoch=100, pop_size=50)
  if(algo=="SARO"):
    model = SARO.OriginalSARO(epoch=100, pop_size=50, se=0.5, mu=50)
  if(algo=="SARO1"):
    model = SARO.DevSARO(epoch=100, pop_size=50, se=0.5, mu=50)
  if(algo=="QSA"):
    model = QSA.OriginalQSA(epoch=100, pop_size=50)
  if(algo=="QSA1"):
    model = QSA.DevQSA(epoch=100, pop_size=50)
  if(algo=="QSA2"):
    model = QSA.OppoQSA(epoch=100, pop_size=50)
  if(algo=="QSA3"):
    model = QSA.LevyQSA(epoch=100, pop_size=50)
  if(algo=="QSA4"):
    model = QSA.ImprovedQSA(epoch=100, pop_size=50)


  if(algo=="ArchOA"):
    model = ArchOA.OriginalArchOA(epoch=100, pop_size=50, c1=2, c2=5, c3=2, c4=0.5, acc_max=0.9, acc_min=0.1)
  if(algo=="ASO"):
    model = ASO.OriginalASO(epoch=100, pop_size=50, alpha=50, beta=0.2)
  if(algo=="CDO"):
    model = CDO.OriginalCDO(epoch=100, pop_size=50)
  if(algo=="EFO"):
    model = EFO.OriginalEFO(epoch=100, pop_size=50, r_rate=0.3, ps_rate=0.85, p_field=0.1, n_field=0.45)
  if(algo=="EFO1"):
    model = EFO.DevEFO(epoch=100, pop_size=50, r_rate=0.3, ps_rate=0.85, p_field=0.1, n_field=0.45)
  if(algo=="EO"):
    model = EO.OriginalEO(epoch=100, pop_size=50)
  if(algo=="EO1"):
    model = EO.AdaptiveEO(epoch=100, pop_size=50)
  if(algo=="EO2"):
    model = EO.ModifiedEO(epoch=100, pop_size=50)
  if(algo=="EVO"):
    model = EVO.OriginalEVO(epoch=100, pop_size=50)
  if(algo=="FLA"):
    model = FLA.OriginalFLA(epoch=100, pop_size=50, C1=0.5, C2=2.0, C3=0.1, C4=0.2, C5=2.0, DD=0.01)
  if(algo=="HGSO"):
    model = HGSO.OriginalHGSO(epoch=100, pop_size=50, n_clusters=3)
  if(algo=="MVO"):
    model = MVO.OriginalMVO(epoch=100, pop_size=50, wep_min=0.2, wep_max=1.0)
  if(algo=="MVO1"):
    model = MVO.DevMVO(epoch=100, pop_size=50, wep_min=0.2, wep_max=1.0)


  if(algo=="NRO"):
    model = NRO.OriginalNRO(epoch=100, pop_size=50)
  if(algo=="RIME"):
    model = RIME.OriginalRIME(epoch=100, pop_size=50, sr=5.0)
  if(algo=="SA"):
    model = SA.OriginalSA(epoch=100, pop_size=50, temp_init=100, step_size=0.1)
  if(algo=="SA1"):
    model = SA.GaussianSA(epoch=100, pop_size=50, temp_init=100, cooling_rate=0.99, scale=0.1)
  if(algo=="SA2"):
    model = SA.SwarmSA(epoch=100, pop_size=50, max_sub_iter=5, t0=1000, t1=1, move_count=5, mutation_rate=0.1, mutation_step_size=0.1,
                        mutation_step_size_damp=0.99)
  if(algo=="WDO"):
    model = WDO.OriginalWDO(epoch=100, pop_size=50, RT=3, g_c=0.2, alp=0.4, c_e=0.4, max_v=0.3)
  if(algo=="TWO"):
    model = TWO.OriginalTWO(epoch=100, pop_size=50)
  if(algo=="TWO1"):
    model = TWO.EnhancedTWO(epoch=100, pop_size=50)
  if(algo=="TWO2"):
    model = TWO.OppoTWO(epoch=100, pop_size=50)
  if(algo=="TWO3"):
    model = TWO.LevyTWO(epoch=100, pop_size=50)
  if(algo=="ABC"):
    model = ABC.OriginalABC(epoch=100, pop_size=50, n_limits=50)
  if(algo=="ACOR"):
    model = ACOR.OriginalACOR(epoch=100, pop_size=50, sample_count=25, intent_factor=0.5, zeta=1.0)
  if(algo=="AGTO"):
    model = AGTO.OriginalAGTO(epoch=100, pop_size=50, p1=0.03, p2=0.8, beta=3.0)
  if(algo=="AGTO1"):
    model = AGTO.MGTO(epoch=100, pop_size=50, pp=0.03)
  if(algo=="BeesA"):
    model = BeesA.OriginalBeesA(epoch=100, pop_size=50, selected_site_ratio=0.5, elite_site_ratio=0.4, selected_site_bee_ratio=0.1, elite_site_bee_ratio=2.0,dance_radius=0.1, dance_reduction=0.99)
  if(algo=="BeesA1"):
    model = BeesA.CleverBookBeesA(epoch=100, pop_size=50, n_elites=16, n_others=4, patch_size=5.0, patch_reduction=0.985, n_sites=3, n_elite_sites=1)
  if(algo=="BeesA2"):
    model = BeesA.ProbBeesA(epoch=100, pop_size=50, recruited_bee_ratio=0.1, dance_radius=0.1, dance_reduction=0.99)
  if(algo=="BES"):
    model = BES.OriginalBES(epoch=100, pop_size=50, a_factor=10, R_factor=1.5, alpha=2.0, c1=2.0, c2=2.0)
  if(algo=="BFO"):
    model = BFO.OriginalBFO(epoch=100, pop_size=50, Ci=0.01, Ped=0.25, Nc=5, Ns=4, d_attract=0.1, w_attract=0.2, h_repels=0.1, w_repels=10)
  if(algo=="BFO1"):
    model = BFO.ABFO(epoch=100, pop_size=50, C_s=0.1, C_e=0.001, Ped=0.01, Ns=4, N_adapt=2, N_split=40)
  if(algo=="ZOA"):
    model = ZOA.OriginalZOA(epoch=100, pop_size=50)
  if(algo=="WOA"):
    model = WOA.OriginalWOA(epoch=100, pop_size=50)
  if(algo=="WOA"):
    model = WOA.HI_WOA(epoch=100, pop_size=50, feedback_max=10)
  if(algo=="WaOA"):
    model = WaOA.OriginalWaOA(epoch=100, pop_size=50)
  if(algo=="TSO"):
    model = TSO.OriginalTSO(epoch=100, pop_size=50)
  if(algo=="TDO"):
    model = TDO.OriginalTDO(epoch=100, pop_size=50)
  if(algo=="STO"):
    model = STO.OriginalSTO(epoch=100, pop_size=50)


  if(algo=="SSpiderO"):
    model = SSpiderO.OriginalSSpiderO(epoch=100, pop_size=50, fp_min=0.65, fp_max=0.9)
  if(algo=="SSpiderA"):
    model = SSpiderA.OriginalSSpiderA(epoch=100, pop_size=50, r_a=1.0, p_c=0.7, p_m=0.1)
  if(algo=="SSO"):
    model = SSO.OriginalSSO(epoch=100, pop_size=50)
  if(algo=="SSA1"):
    model = SSA.OriginalSSA(epoch=100, pop_size=50, ST=0.8, PD=0.2, SD=0.1)
  if(algo=="SSA"):
    model = SSA.DevSSA(epoch=100, pop_size=50, ST=0.8, PD=0.2, SD=0.1)
  if(algo=="SRSR"):
    model = SRSR.OriginalSRSR(epoch=100, pop_size=50)
  if(algo=="SLO"):
    model = SLO.OriginalSLO(epoch=100, pop_size=50)
  if(algo=="SLO2"):
    model = SLO.ModifiedSLO(epoch=100, pop_size=50)
  if(algo=="SLO1"):
    model = SLO.ImprovedSLO(epoch=100, pop_size=50, c1=1.2, c2=1.5)
  if(algo=="SHO"):
    model = SHO.OriginalSHO(epoch=100, pop_size=50, h_factor=5.0, n_trials=10)
  if(algo=="SFO1"):
    model = SFO.OriginalSFO(epoch=100, pop_size=50, pp=0.1, AP=4.0, epsilon=0.0001)
  if(algo=="SFO"):
    model = SFO.ImprovedSFO(epoch=100, pop_size=50, pp=0.1)
  if(algo=="ServalOA"):
    model = ServalOA.OriginalServalOA(epoch=100, pop_size=50)
  if(algo=="SeaHO"):
    model = SeaHO.OriginalSeaHO(epoch=100, pop_size=50)
  if(algo=="SCSO"):
    model = SCSO.OriginalSCSO(epoch=100, pop_size=50)
  if(algo=="POA"):
    model = POA.OriginalPOA(epoch=100, pop_size=50)
  if(algo=="PFA"):
    model = PFA.OriginalPFA(epoch=100, pop_size=50)
  if(algo=="OOA"):
    model = OOA.OriginalOOA(epoch=100, pop_size=50)
  if(algo=="NGO"):
    model = NGO.OriginalNGO(epoch=100, pop_size=50)
  if(algo=="NMRA1"):
    model = NMRA.OriginalNMRA(epoch=100, pop_size=50, pb=0.75)
  if(algo=="NMRA"):
    model = NMRA.ImprovedNMRA(epoch=100, pop_size=50, pb=0.75, pm=0.01)
  if(algo=="MSA"):
    model = MSA.OriginalMSA(epoch=100, pop_size=50, n_best=5, partition=0.5, max_step_size=1.0)
  if(algo=="MRFO1"):
    model = MRFO.OriginalMRFO(epoch=100, pop_size=50, somersault_range=2.0)
  if(algo=="MRFO"):
    model = MRFO.WMQIMRFO(epoch=100, pop_size=50, somersault_range=2.0, pm=0.5)
  if(algo=="MPA"):
    model = MPA.OriginalMPA(epoch=100, pop_size=50)
  if(algo=="MGO"):
    model = MGO.OriginalMGO(epoch=100, pop_size=50)
  if(algo=="MFO"):
    model = MFO.OriginalMFO(epoch=100, pop_size=50)
  if(algo=="JA2"):
    model = JA.OriginalJA(epoch=100, pop_size=50)
  if(algo=="JA1"):
    model = JA.LevyJA(epoch=100, pop_size=50)
  if(algo=="JA"):
    model = JA.DevJA(epoch=100, pop_size=50)
  if(algo=="HHO"):
    model = HHO.OriginalHHO(epoch=100, pop_size=50)
  if(algo=="HGS"):
    model = HGS.OriginalHGS(epoch=100, pop_size=50, PUP=0.08, LH=10000)
  if(algo=="HBA"):
    model = HBA.OriginalHBA(epoch=100, pop_size=50)
  if(algo=="GWO3"):
    model = GWO.OriginalGWO(epoch=100, pop_size=50)
  if(algo=="GWO2"):
    model = GWO.GWO_WOA(epoch=100, pop_size=50)
  if(algo=="GWO1"):
    model = GWO.RW_GWO(epoch=100, pop_size=50)
  if(algo=="GTO2"):
    model = GTO.OriginalGTO(epoch=100, pop_size=50, A=0.4, H=2.0)
  if(algo=="GTO1"):
    model = GTO.Matlab101GTO(epoch=100, pop_size=50)
  if(algo=="GTO"):
    model = GTO.Matlab102GTO(epoch=100, pop_size=50)
  if(algo=="GOA"):
    model = GOA.OriginalGOA(epoch=100, pop_size=50, c_min=0.00004, c_max=1.0)
  if(algo=="GJO"):
    model = GJO.OriginalGJO(epoch=100, pop_size=50)
  if(algo=="FOX"):
    model = FOX.OriginalFOX(epoch=100, pop_size=50, c1=0.18, c2=0.82)
  if(algo=="FOA1"):
    model = FOA.OriginalFOA(epoch=100, pop_size=50)
  if(algo=="FOA"):
    model = FOA.WhaleFOA(epoch=100, pop_size=50)
  if(algo=="FOA2"):
    model = FOA.DevFOA(epoch=100, pop_size=50)
  if(algo=="FFO"):
    model = FFO.OriginalFFO(epoch=100, pop_size=50)
  if(algo=="FFA"):
    model = FFA.OriginalFFA(epoch=100, pop_size=50, gamma=0.001, beta_base=2, alpha=0.2, alpha_damp=0.99, delta=0.05, exponent=2)
  if(algo=="FA"):
    model = FA.OriginalFA(epoch=100, pop_size=50, max_sparks=50, p_a=0.04, p_b=0.8, max_ea=40, m_sparks=50)
  if(algo=="ESOA"):
    model = ESOA.OriginalESOA(epoch=100, pop_size=50)
  if(algo=="EHO"):
    model = EHO.OriginalEHO(epoch=100, pop_size=50, alpha=0.5, beta=0.5, n_clans=5)
  if(algo=="DO"):
    model = DO.OriginalDO(epoch=100, pop_size=50)
  if(algo=="DMOA1"):
    model = DMOA.OriginalDMOA(epoch=100, pop_size=50, n_baby_sitter=3, peep=2)
  if(algo=="DMOA"):
    model = DMOA.DevDMOA(epoch=100, pop_size=50, peep=2)
  if(algo=="CSO"):
    model = CSO.OriginalCSO(epoch=100, pop_size=50, mixture_ratio=0.15, smp=5, spc=False, cdc=0.8, srd=0.15, c1=0.4, w_min=0.4, w_max=0.9)
  if(algo=="CSA"):
    model = CSA.OriginalCSA(epoch=100, pop_size=50, p_a=0.3)
  if(algo=="CoatiOA"):
    model = CoatiOA.OriginalCoatiOA(epoch=100, pop_size=50)
  if(algo=="COA"):
    model = COA.OriginalCOA(epoch=100, pop_size=50, n_coyotes=5)
  if(algo=="BSA"):
    model = BSA.OriginalBSA(epoch=100, pop_size=50, ff=10, pff=0.8, c1=1.5, c2=1.5, a1=1.0, a2=1.0, fc=0.5)

  g_best = model.solve(problem_dict, mode="thread", n_workers=26 )
  best_position=g_best.solution
  best_fitness=g_best.solution
  print(f"Solution: {best_position}, Fitness: {best_fitness}")
  Fun1(g_best.solution)
  s=[round(num,0) for num in best_position]
  print(s)

  #s=np.round(best_position,0)
  p={}
  exetime= time.time() - start_time
  #print(s)
  data1 = {"name": s, "exetime": str(exetime)}
  # !mkdir -p "/content/"{algo}
  #print(data1)
  with open(algo+"/sample_"+str(size1)+"_"+str(vmcount1)+".json", "w") as outfile:
      json.dump(data1, outfile)
  f.close()

# %%
vm=5
count=10000
number=100

# %%
#from google.colab import drive
#drive.mount('/content/drive')
import json

with open("data_10000_5.json", "r") as f:
    data = json.load(f)

# %%
import shutil
import threading
def fun2(tif_file,algo):
        t1 = threading.Thread(target=optimize, args=(tif_file, algo,100,vmcount1))
        t2 = threading.Thread(target=optimize, args=(tif_file, algo,500,vmcount1))
        t3 = threading.Thread(target=optimize, args=(tif_file, algo,1000,vmcount1))
        t4 = threading.Thread(target=optimize, args=(tif_file, algo,1500,vmcount1))
        t5 = threading.Thread(target=optimize, args=(tif_file, algo,2000,vmcount1))
        t6 = threading.Thread(target=optimize, args=(tif_file, algo,2500,vmcount1))
        t1.start()
        t2.start()
        t3.start()
        t4.start()
        t5.start()
        t6.start()
        t1.join()
        t2.join()
        t3.join()
        t4.join()
        t5.join()
        t6.join()
        print(f"Finished {algo}")
        # absolute path
        # %cp -r /content/{algo} "/content/drive/MyDrive/Cloudsim/exe"
        #dst_path = r"C:\Users\CSE\Desktop\punit\Dropbox\EXE\5\0Done"
        #shutil.move(algo, dst_path)
        f.close()

# %%
algo = [
     "ASO", "CDO", "EFO", "EFO1","HBO"
    ]

tif_file="data_10000_5.json"
for i in range(len(algo)):
    try:
      fun2(tif_file, algo[i])
    except:
      print("An exception occurred")
# Out:
# 2025/07/02 11:39:13 AM, INFO, mealpy.physics_based.ASO.OriginalASO: Solving single objective optimization problem.
# Exception in thread 2025/07/02 11:39:13 AM, INFO, mealpy.physics_based.ASO.OriginalASO: Solving single objective optimization problem.
# Thread-65 (optimize):
# Traceback (most recent call last):
#   File "C:\Program Files\Python312\Lib\threading.py", line 1073, in _bootstrap_inner
# Exception in thread Thread-66 (optimize):
# Traceback (most recent call last):
#   File "C:\Program Files\Python312\Lib\threading.py", line 1073, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Asus\AppData\Roaming\Python\Python312\site-packages\ipykernel\ipkernel.py", line 766, in run_closure
#     self.run()
#   File "C:\Users\Asus\AppData\Roaming\Python\Python312\site-packages\ipykernel\ipkernel.py", line 766, in run_closure
# 2025/07/02 11:39:13 AM, INFO, mealpy.physics_based.ASO.OriginalASO: Solving single objective optimization problem.
# Exception in thread Thread-67 (optimize):
# Traceback (most recent call last):
#   File "C:\Program Files\Python312\Lib\threading.py", line 1073, in _bootstrap_inner
# 2025/07/02 11:39:13 AM, INFO, mealpy.physics_based.ASO.OriginalASO: Solving single objective optimization problem.
# Exception in thread     _threading_Thread_run(self)
#   File "C:\Program Files\Python312\Lib\threading.py", line 1010, in run
# Thread-68 (optimize):
# Traceback (most recent call last):
#   File "C:\Program Files\Python312\Lib\threading.py", line 1073, in _bootstrap_inner
# 2025/07/02 11:39:13 AM, INFO, mealpy.physics_based.ASO.OriginalASO: Solving single objective optimization problem.
# Exception in thread Thread-70 (optimize):
# Traceback (most recent call last):
#   File "C:\Program Files\Python312\Lib\threading.py", line 1073, in _bootstrap_inner
# 2025/07/02 11:39:13 AM, INFO, mealpy.physics_based.ASO.OriginalASO: Solving single objective optimization problem.
#     _threading_Thread_run(self)
#   File "C:\Program Files\Python312\Lib\threading.py", line 1010, in run
#     self.run()
#   File "C:\Users\Asus\AppData\Roaming\Python\Python312\site-packages\ipykernel\ipkernel.py", line 766, in run_closure
#     self.run()
#   File "C:\Users\Asus\AppData\Roaming\Python\Python312\site-packages\ipykernel\ipkernel.py", line 766, in run_closure
#     self.run()
#   File "C:\Users\Asus\AppData\Roaming\Python\Python312\site-packages\ipykernel\ipkernel.py", line 766, in run_closure
#     _threading_Thread_run(self)
#   File "C:\Program Files\Python312\Lib\threading.py", line 1010, in run
# Exception in thread Thread-69 (optimize):
# Traceback (most recent call last):
#   File "C:\Program Files\Python312\Lib\threading.py", line 1073, in _bootstrap_inner
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\Asus\AppData\Local\Temp\ipykernel_14716\1739199214.py", line 444, in optimize
#     _threading_Thread_run(self)
#   File "C:\Program Files\Python312\Lib\threading.py", line 1010, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\Asus\AppData\Local\Temp\ipykernel_14716\1739199214.py", line 444, in optimize
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\Asus\AppData\Local\Temp\ipykernel_14716\1739199214.py", line 444, in optimize
#     self.run()
#   File "C:\Users\Asus\AppData\Roaming\Python\Python312\site-packages\ipykernel\ipkernel.py", line 766, in run_closure
#     _threading_Thread_run(self)
#   File "C:\Program Files\Python312\Lib\threading.py", line 1010, in run
#     _threading_Thread_run(self)
#   File "C:\Program Files\Python312\Lib\threading.py", line 1010, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\Asus\AppData\Local\Temp\ipykernel_14716\1739199214.py", line 444, in optimize
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\Asus\AppData\Local\Temp\ipykernel_14716\1739199214.py", line 444, in optimize
#   File "C:\Users\Asus\AppData\Roaming\Python\Python312\site-packages\mealpy\optimizer.py", line 224, in solve
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\Asus\AppData\Local\Temp\ipykernel_14716\1739199214.py", line 444, in optimize
#   File "C:\Users\Asus\AppData\Roaming\Python\Python312\site-packages\mealpy\optimizer.py", line 224, in solve
#   File "C:\Users\Asus\AppData\Roaming\Python\Python312\site-packages\mealpy\optimizer.py", line 224, in solve
#     self.check_mode_and_workers(mode, n_workers)
#   File "C:\Users\Asus\AppData\Roaming\Python\Python312\site-packages\mealpy\optimizer.py", line 176, in check_mode_and_workers
#   File "C:\Users\Asus\AppData\Roaming\Python\Python312\site-packages\mealpy\optimizer.py", line 224, in solve
#   File "C:\Users\Asus\AppData\Roaming\Python\Python312\site-packages\mealpy\optimizer.py", line 224, in solve
#     self.check_mode_and_workers(mode, n_workers)
#   File "C:\Users\Asus\AppData\Roaming\Python\Python312\site-packages\mealpy\optimizer.py", line 176, in check_mode_and_workers
#     self.check_mode_and_workers(mode, n_workers)
#   File "C:\Users\Asus\AppData\Roaming\Python\Python312\site-packages\mealpy\optimizer.py", line 176, in check_mode_and_workers
#     self.n_workers = self.validator.check_int("n_workers", n_workers, [2, min(32, os.cpu_count() + 4)])
#                      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Asus\AppData\Roaming\Python\Python312\site-packages\mealpy\utils\validator.py", line 54, in check_int
#     self.check_mode_and_workers(mode, n_workers)
#   File "C:\Users\Asus\AppData\Roaming\Python\Python312\site-packages\mealpy\optimizer.py", line 176, in check_mode_and_workers
#     self.n_workers = self.validator.check_int("n_workers", n_workers, [2, min(32, os.cpu_count() + 4)])
#                      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Asus\AppData\Roaming\Python\Python312\site-packages\mealpy\utils\validator.py", line 54, in check_int
#     raise ValueError(f"'{name}' is an integer {bound}.")
# ValueError: 'n_workers' is an integer and value should be in range: [2, 20].
#     self.check_mode_and_workers(mode, n_workers)
#   File "C:\Users\Asus\AppData\Roaming\Python\Python312\site-packages\mealpy\optimizer.py", line 176, in check_mode_and_workers
#     self.n_workers = self.validator.check_int("n_workers", n_workers, [2, min(32, os.cpu_count() + 4)])
#                      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Asus\AppData\Roaming\Python\Python312\site-packages\mealpy\utils\validator.py", line 54, in check_int
#     raise ValueError(f"'{name}' is an integer {bound}.")
# ValueError: 'n_workers' is an integer and value should be in range: [2, 20].
#     self.n_workers = self.validator.check_int("n_workers", n_workers, [2, min(32, os.cpu_count() + 4)])
#                      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Asus\AppData\Roaming\Python\Python312\site-packages\mealpy\utils\validator.py", line 54, in check_int
#   File "C:\Users\Asus\AppData\Roaming\Python\Python312\site-packages\mealpy\optimizer.py", line 224, in solve
#     raise ValueError(f"'{name}' is an integer {bound}.")
# ValueError: 'n_workers' is an integer and value should be in range: [2, 20].
#     self.n_workers = self.validator.check_int("n_workers", n_workers, [2, min(32, os.cpu_count() + 4)])
#                      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Asus\AppData\Roaming\Python\Python312\site-packages\mealpy\utils\validator.py", line 54, in check_int
#     self.check_mode_and_workers(mode, n_workers)
#   File "C:\Users\Asus\AppData\Roaming\Python\Python312\site-packages\mealpy\optimizer.py", line 176, in check_mode_and_workers
#     raise ValueError(f"'{name}' is an integer {bound}.")
# ValueError: 'n_workers' is an integer and value should be in range: [2, 20].
#     raise ValueError(f"'{name}' is an integer {bound}.")
# ValueError: 'n_workers' is an integer and value should be in range: [2, 20].
#     self.n_workers = self.validator.check_int("n_workers", n_workers, [2, min(32, os.cpu_count() + 4)])
#                      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Asus\AppData\Roaming\Python\Python312\site-packages\mealpy\utils\validator.py", line 54, in check_int
#     raise ValueError(f"'{name}' is an integer {bound}.")
# ValueError: 'n_workers' is an integer and value should be in range: [2, 20].
# 2025/07/02 11:39:13 AM, INFO, mealpy.physics_based.CDO.OriginalCDO: Solving single objective optimization problem.
# Exception in thread 2025/07/02 11:39:13 AM, INFO, mealpy.physics_based.CDO.OriginalCDO: Solving single objective optimization problem.
# Thread-71 (optimize):
# Traceback (most recent call last):
#   File "C:\Program Files\Python312\Lib\threading.py", line 1073, in _bootstrap_inner
# Exception in thread Thread-72 (optimize):
# Traceback (most recent call last):
#   File "C:\Program Files\Python312\Lib\threading.py", line 1073, in _bootstrap_inner
# 2025/07/02 11:39:13 AM, INFO, mealpy.physics_based.CDO.OriginalCDO: Solving single objective optimization problem.
#     self.run()
#   File "C:\Users\Asus\AppData\Roaming\Python\Python312\site-packages\ipykernel\ipkernel.py", line 766, in run_closure
#     self.run()
#   File "C:\Users\Asus\AppData\Roaming\Python\Python312\site-packages\ipykernel\ipkernel.py", line 766, in run_closure
# Finished ASO
# An exception occurred
# Exception in thread Thread-73 (optimize):
# Traceback (most recent call last):
#   File "C:\Program Files\Python312\Lib\threading.py", line 1073, in _bootstrap_inner
# 2025/07/02 11:39:13 AM, INFO, mealpy.physics_based.CDO.OriginalCDO: Solving single objective optimization problem.
#     _threading_Thread_run(self)
#   File "C:\Program Files\Python312\Lib\threading.py", line 1010, in run
#     _threading_Thread_run(self)
#   File "C:\Program Files\Python312\Lib\threading.py", line 1010, in run
#     self.run()
#   File "C:\Users\Asus\AppData\Roaming\Python\Python312\site-packages\ipykernel\ipkernel.py", line 766, in run_closure
# Exception in thread Thread-75 (optimize):
# Traceback (most recent call last):
#   File "C:\Program Files\Python312\Lib\threading.py", line 1073, in _bootstrap_inner
# 2025/07/02 11:39:13 AM, INFO, mealpy.physics_based.CDO.OriginalCDO: Solving single objective optimization problem.
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\Asus\AppData\Local\Temp\ipykernel_14716\1739199214.py", line 444, in optimize
#     _threading_Thread_run(self)
#   File "C:\Program Files\Python312\Lib\threading.py", line 1010, in run
#     self.run()
#   File "C:\Users\Asus\AppData\Roaming\Python\Python312\site-packages\ipykernel\ipkernel.py", line 766, in run_closure
# Exception in thread Thread-74 (optimize):
# Traceback (most recent call last):
#   File "C:\Program Files\Python312\Lib\threading.py", line 1073, in _bootstrap_inner
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\Asus\AppData\Local\Temp\ipykernel_14716\1739199214.py", line 444, in optimize
# 2025/07/02 11:39:13 AM, INFO, mealpy.physics_based.CDO.OriginalCDO: Solving single objective optimization problem.
#     _threading_Thread_run(self)
#   File "C:\Program Files\Python312\Lib\threading.py", line 1010, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\Asus\AppData\Local\Temp\ipykernel_14716\1739199214.py", line 444, in optimize
#   File "C:\Users\Asus\AppData\Roaming\Python\Python312\site-packages\mealpy\optimizer.py", line 224, in solve
# Exception in thread     self.run()
#   File "C:\Users\Asus\AppData\Roaming\Python\Python312\site-packages\mealpy\optimizer.py", line 224, in solve
# Thread-76 (optimize)  File "C:\Users\Asus\AppData\Roaming\Python\Python312\site-packages\ipykernel\ipkernel.py", line 766, in run_closure
#     self.check_mode_and_workers(mode, n_workers):
#
#       File "C:\Users\Asus\AppData\Roaming\Python\Python312\site-packages\mealpy\optimizer.py", line 224, in solve
# self._target(*self._args, **self._kwargs)
#       File "C:\Users\Asus\AppData\Roaming\Python\Python312\site-packages\mealpy\optimizer.py", line 176, in check_mode_and_workers
#     _threading_Thread_run(self)Traceback (most recent call last):
# self.check_mode_and_workers(mode, n_workers)
#
#   File "C:\Users\Asus\AppData\Local\Temp\ipykernel_14716\1739199214.py", line 444, in optimize
#   File "C:\Program Files\Python312\Lib\threading.py", line 1073, in _bootstrap_inner
#       File "C:\Program Files\Python312\Lib\threading.py", line 1010, in run
#     self.check_mode_and_workers(mode, n_workers)  File "C:\Users\Asus\AppData\Roaming\Python\Python312\site-packages\mealpy\optimizer.py", line 176, in check_mode_and_workers
# self.n_workers = self.validator.check_int("n_workers", n_workers, [2, min(32, os.cpu_count() + 4)])
#
#   File "C:\Users\Asus\AppData\Roaming\Python\Python312\site-packages\mealpy\optimizer.py", line 176, in check_mode_and_workers
#             self.n_workers = self.validator.check_int("n_workers", n_workers, [2, min(32, os.cpu_count() + 4)])     self.run()
#  self._target(*self._args, **self._kwargs)
#   File "C:\Users\Asus\AppData\Roaming\Python\Python312\site-packages\mealpy\optimizer.py", line 224, in solve
# self.n_workers = self.validator.check_int("n_workers", n_workers, [2, min(32, os.cpu_count() + 4)])
#
#           File "C:\Users\Asus\AppData\Roaming\Python\Python312\site-packages\ipykernel\ipkernel.py", line 766, in run_closure
#    File "C:\Users\Asus\AppData\Local\Temp\ipykernel_14716\1739199214.py", line 444, in optimize
#               self.check_mode_and_workers(mode, n_workers)
#           _threading_Thread_run(self)  File "C:\Users\Asus\AppData\Roaming\Python\Python312\site-packages\mealpy\optimizer.py", line 176, in check_mode_and_workers
#
#    File "C:\Users\Asus\AppData\Roaming\Python\Python312\site-packages\mealpy\optimizer.py", line 224, in solve
#    ^   File "C:\Program Files\Python312\Lib\threading.py", line 1010, in run
#      ^   self.n_workers = self.validator.check_int("n_workers", n_workers, [2, min(32, os.cpu_count() + 4)])      ^
#  self.check_mode_and_workers(mode, n_workers)
#   ^       ^^^ self._target(*self._args, **self._kwargs)   File "C:\Users\Asus\AppData\Roaming\Python\Python312\site-packages\mealpy\optimizer.py", line 176, in check_mode_and_workers
# ^
#  ^   ^    File "C:\Users\Asus\AppData\Local\Temp\ipykernel_14716\1739199214.py", line 444, in optimize
#  ^      ^^ ^self.n_workers = self.validator.check_int("n_workers", n_workers, [2, min(32, os.cpu_count() + 4)])^^ ^^
# ^ ^^^^^^^^ ^^^^      ^^^^  File "C:\Users\Asus\AppData\Roaming\Python\Python312\site-packages\mealpy\optimizer.py", line 224, in solve
#     ^^^^     ^^^^^^^^^   ^^  ^^^^^^ ^^  ^    self.check_mode_and_workers(mode, n_workers)
# ^ ^^^^^^^^^^ ^^^^^^^^  File "C:\Users\Asus\AppData\Roaming\Python\Python312\site-packages\mealpy\optimizer.py", line 176, in check_mode_and_workers
#  ^^^^^^^^  ^^^^^    self.n_workers = self.validator.check_int("n_workers", n_workers, [2, min(32, os.cpu_count() + 4)])
#  ^^^^^ ^^  ^^^^^ ^^^  ^^^^^^^ ^^^^^^   ^^^^^^^^  ^^^^^^^^^ ^^^^^ ^^^^^^ ^^^^^^^^^^   ^^^^^^^^^^^^^^  ^^^^^^ ^^^^^^^^^  ^^^^^^^^^^  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ^^^^^^^^^^^^^^^^^^  File "C:\Users\Asus\AppData\Roaming\Python\Python312\site-packages\mealpy\utils\validator.py", line 54, in check_int
# ^^^^^^^^^^^^^^^^^^^    ^^^^^^raise ValueError(f"'{name}' is an integer {bound}.")^^^^^^^^^
# ^^^^^^^^^^^^^^^^^^^^ValueError: 'n_workers' is an integer and value should be in range: [2, 20].^^^^^^^^^^^^^^
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ^^^^^^^^  File "C:\Users\Asus\AppData\Roaming\Python\Python312\site-packages\mealpy\utils\validator.py", line 54, in check_int
# ^^^^^^^^^^^^^^^^^^^^^
# ^^    raise ValueError(f"'{name}' is an integer {bound}.")
# ^^^^^
# ^ValueError^  File "C:\Users\Asus\AppData\Roaming\Python\Python312\site-packages\mealpy\utils\validator.py", line 54, in check_int
#   File "C:\Users\Asus\AppData\Roaming\Python\Python312\site-packages\mealpy\utils\validator.py", line 54, in check_int
# : ^^'n_workers' is an integer and value should be in range: [2, 20].^^^
# ^    ^raise ValueError(f"'{name}' is an integer {bound}.")^^raise ValueError(f"'{name}' is an integer {bound}.")
# ^^
# ^^ValueError^^: 'n_workers' is an integer and value should be in range: [2, 20].^^
# ValueError^^: 'n_workers' is an integer and value should be in range: [2, 20].
# ^^^^^^^^
#
#   File "C:\Users\Asus\AppData\Roaming\Python\Python312\site-packages\mealpy\utils\validator.py", line 54, in check_int
#   File "C:\Users\Asus\AppData\Roaming\Python\Python312\site-packages\mealpy\utils\validator.py", line 54, in check_int
#     raise ValueError(f"'{name}' is an integer {bound}.")
# ValueError: 'n_workers' is an integer and value should be in range: [2, 20].
#     raise ValueError(f"'{name}' is an integer {bound}.")
# ValueError: 'n_workers' is an integer and value should be in range: [2, 20].
# 2025/07/02 11:39:13 AM, INFO, mealpy.physics_based.EFO.OriginalEFO: Solving single objective optimization problem.
# Exception in thread Thread-77 (optimize):
# Traceback (most recent call last):
#   File "C:\Program Files\Python312\Lib\threading.py", line 1073, in _bootstrap_inner
# 2025/07/02 11:39:13 AM, INFO, mealpy.physics_based.EFO.OriginalEFO: Solving single objective optimization problem.
# Exception in thread Thread-78 (optimize):
# Traceback (most recent call last):
#   File "C:\Program Files\Python312\Lib\threading.py", line 1073, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Asus\AppData\Roaming\Python\Python312\site-packages\ipykernel\ipkernel.py", line 766, in run_closure
# 2025/07/02 11:39:13 AM, INFO, mealpy.physics_based.EFO.OriginalEFO: Solving single objective optimization problem.
# Exception in thread 2025/07/02 11:39:13 AM, INFO, mealpy.physics_based.EFO.OriginalEFO: Solving single objective optimization problem.
# Thread-79 (optimize):
# Traceback (most recent call last):
#   File "C:\Program Files\Python312\Lib\threading.py", line 1073, in _bootstrap_inner
#     _threading_Thread_run(self)
#   File "C:\Program Files\Python312\Lib\threading.py", line 1010, in run
# Exception in thread Thread-80 (optimize):
# Traceback (most recent call last):
#   File "C:\Program Files\Python312\Lib\threading.py", line 1073, in _bootstrap_inner
# 2025/07/02 11:39:13 AM, INFO, mealpy.physics_based.EFO.OriginalEFO: Solving single objective optimization problem.
#     self.run()
#   File "C:\Users\Asus\AppData\Roaming\Python\Python312\site-packages\ipykernel\ipkernel.py", line 766, in run_closure
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\Asus\AppData\Local\Temp\ipykernel_14716\1739199214.py", line 444, in optimize
#     self.run()
#   File "C:\Users\Asus\AppData\Roaming\Python\Python312\site-packages\ipykernel\ipkernel.py", line 766, in run_closure
# Exception in thread     _threading_Thread_run(self)
#   File "C:\Program Files\Python312\Lib\threading.py", line 1010, in run
# 2025/07/02 11:39:13 AM, INFO, mealpy.physics_based.EFO.OriginalEFO: Solving single objective optimization problem.
# Thread-82 (optimize):
# Traceback (most recent call last):
#   File "C:\Program Files\Python312\Lib\threading.py", line 1073, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Asus\AppData\Roaming\Python\Python312\site-packages\ipykernel\ipkernel.py", line 766, in run_closure
#     _threading_Thread_run(self)
#   File "C:\Program Files\Python312\Lib\threading.py", line 1010, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\Asus\AppData\Local\Temp\ipykernel_14716\1739199214.py", line 444, in optimize
# Exception in thread Thread-81 (optimize):
# Traceback (most recent call last):
#   File "C:\Program Files\Python312\Lib\threading.py", line 1073, in _bootstrap_inner
#   File "C:\Users\Asus\AppData\Roaming\Python\Python312\site-packages\mealpy\optimizer.py", line 224, in solve
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\Asus\AppData\Local\Temp\ipykernel_14716\1739199214.py", line 444, in optimize
#     self.run()
#   File "C:\Users\Asus\AppData\Roaming\Python\Python312\site-packages\ipykernel\ipkernel.py", line 766, in run_closure
#     _threading_Thread_run(self)
#   File "C:\Program Files\Python312\Lib\threading.py", line 1010, in run
#     self.check_mode_and_workers(mode, n_workers)
#   File "C:\Users\Asus\AppData\Roaming\Python\Python312\site-packages\mealpy\optimizer.py", line 176, in check_mode_and_workers
#     self.run()
#   File "C:\Users\Asus\AppData\Roaming\Python\Python312\site-packages\ipykernel\ipkernel.py", line 766, in run_closure
#     _threading_Thread_run(self)
#   File "C:\Program Files\Python312\Lib\threading.py", line 1010, in run
#   File "C:\Users\Asus\AppData\Roaming\Python\Python312\site-packages\mealpy\optimizer.py", line 224, in solve
#     self.n_workers = self.validator.check_int("n_workers", n_workers, [2, min(32, os.cpu_count() + 4)])
#                      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Asus\AppData\Roaming\Python\Python312\site-packages\mealpy\utils\validator.py", line 54, in check_int
#     _threading_Thread_run(self)
#   File "C:\Program Files\Python312\Lib\threading.py", line 1010, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\Asus\AppData\Local\Temp\ipykernel_14716\1739199214.py", line 444, in optimize
#   File "C:\Users\Asus\AppData\Roaming\Python\Python312\site-packages\mealpy\optimizer.py", line 224, in solve
#     raise ValueError(f"'{name}' is an integer {bound}.")
# ValueError: 'n_workers' is an integer and value should be in range: [2, 20].
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\Asus\AppData\Local\Temp\ipykernel_14716\1739199214.py", line 444, in optimize
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\Asus\AppData\Local\Temp\ipykernel_14716\1739199214.py", line 444, in optimize
#     self.check_mode_and_workers(mode, n_workers)
#   File "C:\Users\Asus\AppData\Roaming\Python\Python312\site-packages\mealpy\optimizer.py", line 176, in check_mode_and_workers
#     self.check_mode_and_workers(mode, n_workers)
#   File "C:\Users\Asus\AppData\Roaming\Python\Python312\site-packages\mealpy\optimizer.py", line 176, in check_mode_and_workers
#     self.n_workers = self.validator.check_int("n_workers", n_workers, [2, min(32, os.cpu_count() + 4)])
#                      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Asus\AppData\Roaming\Python\Python312\site-packages\mealpy\utils\validator.py", line 54, in check_int
#   File "C:\Users\Asus\AppData\Roaming\Python\Python312\site-packages\mealpy\optimizer.py", line 224, in solve
#     self.n_workers = self.validator.check_int("n_workers", n_workers, [2, min(32, os.cpu_count() + 4)])
#                      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Asus\AppData\Roaming\Python\Python312\site-packages\mealpy\utils\validator.py", line 54, in check_int
#     raise ValueError(f"'{name}' is an integer {bound}.")
# ValueError: 'n_workers' is an integer and value should be in range: [2, 20].
#     self.check_mode_and_workers(mode, n_workers)
#   File "C:\Users\Asus\AppData\Roaming\Python\Python312\site-packages\mealpy\optimizer.py", line 176, in check_mode_and_workers
#   File "C:\Users\Asus\AppData\Roaming\Python\Python312\site-packages\mealpy\optimizer.py", line 224, in solve
#   File "C:\Users\Asus\AppData\Roaming\Python\Python312\site-packages\mealpy\optimizer.py", line 224, in solve
#     raise ValueError(f"'{name}' is an integer {bound}.")
# ValueError: 'n_workers' is an integer and value should be in range: [2, 20].
#     self.n_workers = self.validator.check_int("n_workers", n_workers, [2, min(32, os.cpu_count() + 4)])
#                      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Asus\AppData\Roaming\Python\Python312\site-packages\mealpy\utils\validator.py", line 54, in check_int
#     self.check_mode_and_workers(mode, n_workers)
#   File "C:\Users\Asus\AppData\Roaming\Python\Python312\site-packages\mealpy\optimizer.py", line 176, in check_mode_and_workers
#     self.check_mode_and_workers(mode, n_workers)
#   File "C:\Users\Asus\AppData\Roaming\Python\Python312\site-packages\mealpy\optimizer.py", line 176, in check_mode_and_workers
#     self.n_workers = self.validator.check_int("n_workers", n_workers, [2, min(32, os.cpu_count() + 4)])
#                      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Asus\AppData\Roaming\Python\Python312\site-packages\mealpy\utils\validator.py", line 54, in check_int
#     raise ValueError(f"'{name}' is an integer {bound}.")
# ValueError: 'n_workers' is an integer and value should be in range: [2, 20].
#     self.n_workers = self.validator.check_int("n_workers", n_workers, [2, min(32, os.cpu_count() + 4)])
#                      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Asus\AppData\Roaming\Python\Python312\site-packages\mealpy\utils\validator.py", line 54, in check_int
#     raise ValueError(f"'{name}' is an integer {bound}.")
# ValueError: 'n_workers' is an integer and value should be in range: [2, 20].
#     raise ValueError(f"'{name}' is an integer {bound}.")
# ValueError: 'n_workers' is an integer and value should be in range: [2, 20].
# 2025/07/02 11:39:13 AM, INFO, mealpy.physics_based.EFO.DevEFO: Solving single objective optimization problem.
# Exception in thread Thread-83 (optimize):
# Traceback (most recent call last):
#   File "C:\Program Files\Python312\Lib\threading.py", line 1073, in _bootstrap_inner
# 2025/07/02 11:39:13 AM, INFO, mealpy.physics_based.EFO.DevEFO: Solving single objective optimization problem.
#     self.run()
#   File "C:\Users\Asus\AppData\Roaming\Python\Python312\site-packages\ipykernel\ipkernel.py", line 766, in run_closure
# Finished CDO
# An exception occurred
# Finished EFO
# An exception occurred
# Exception in thread Thread-84 (optimize):
# Traceback (most recent call last):
#   File "C:\Program Files\Python312\Lib\threading.py", line 1073, in _bootstrap_inner
# 2025/07/02 11:39:13 AM, INFO, mealpy.physics_based.EFO.DevEFO: Solving single objective optimization problem.
#     self.run()
#   File "C:\Users\Asus\AppData\Roaming\Python\Python312\site-packages\ipykernel\ipkernel.py", line 766, in run_closure
#     _threading_Thread_run(self)
#   File "C:\Program Files\Python312\Lib\threading.py", line 1010, in run
#     _threading_Thread_run(self)
#   File "C:\Program Files\Python312\Lib\threading.py", line 1010, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\Asus\AppData\Local\Temp\ipykernel_14716\1739199214.py", line 444, in optimize
# Exception in thread 2025/07/02 11:39:13 AM, INFO, mealpy.physics_based.EFO.DevEFO: Solving single objective optimization problem.
# Thread-85 (optimize):
# Traceback (most recent call last):
#   File "C:\Program Files\Python312\Lib\threading.py", line 1073, in _bootstrap_inner
# Exception in thread Thread-87 (optimize):
# Traceback (most recent call last):
#   File "C:\Program Files\Python312\Lib\threading.py", line 1073, in _bootstrap_inner
# 2025/07/02 11:39:13 AM, INFO, mealpy.physics_based.EFO.DevEFO: Solving single objective optimization problem.
#     self.run()
#   File "C:\Users\Asus\AppData\Roaming\Python\Python312\site-packages\ipykernel\ipkernel.py", line 766, in run_closure
# Exception in thread Thread-86 (optimize):
# Traceback (most recent call last):
#   File "C:\Program Files\Python312\Lib\threading.py", line 1073, in _bootstrap_inner
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\Asus\AppData\Local\Temp\ipykernel_14716\1739199214.py", line 444, in optimize
#   File "C:\Users\Asus\AppData\Roaming\Python\Python312\site-packages\mealpy\optimizer.py", line 224, in solve
# 2025/07/02 11:39:13 AM, INFO, mealpy.physics_based.EFO.DevEFO: Solving single objective optimization problem.
#     self.run()
#   File "C:\Users\Asus\AppData\Roaming\Python\Python312\site-packages\ipykernel\ipkernel.py", line 766, in run_closure
# Exception in thread     _threading_Thread_run(self)
#   File "C:\Program Files\Python312\Lib\threading.py", line 1010, in run
#     self.check_mode_and_workers(mode, n_workers)
#   File "C:\Users\Asus\AppData\Roaming\Python\Python312\site-packages\mealpy\optimizer.py", line 176, in check_mode_and_workers
# Thread-88 (optimize):
# Traceback (most recent call last):
#   File "C:\Program Files\Python312\Lib\threading.py", line 1073, in _bootstrap_inner
#     _threading_Thread_run(self)
#   File "C:\Program Files\Python312\Lib\threading.py", line 1010, in run
#     self.run()
#   File "C:\Users\Asus\AppData\Roaming\Python\Python312\site-packages\ipykernel\ipkernel.py", line 766, in run_closure
#   File "C:\Users\Asus\AppData\Roaming\Python\Python312\site-packages\mealpy\optimizer.py", line 224, in solve
#     self.n_workers = self.validator.check_int("n_workers", n_workers, [2, min(32, os.cpu_count() + 4)])
#                      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Asus\AppData\Roaming\Python\Python312\site-packages\mealpy\utils\validator.py", line 54, in check_int
#     self.run()
#   File "C:\Users\Asus\AppData\Roaming\Python\Python312\site-packages\ipykernel\ipkernel.py", line 766, in run_closure
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\Asus\AppData\Local\Temp\ipykernel_14716\1739199214.py", line 444, in optimize
#     _threading_Thread_run(self)
#   File "C:\Program Files\Python312\Lib\threading.py", line 1010, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\Asus\AppData\Local\Temp\ipykernel_14716\1739199214.py", line 444, in optimize
#     self.check_mode_and_workers(mode, n_workers)
#   File "C:\Users\Asus\AppData\Roaming\Python\Python312\site-packages\mealpy\optimizer.py", line 176, in check_mode_and_workers
#     raise ValueError(f"'{name}' is an integer {bound}.")
# ValueError: 'n_workers' is an integer and value should be in range: [2, 20].
#     self.n_workers = self.validator.check_int("n_workers", n_workers, [2, min(32, os.cpu_count() + 4)])
#                      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Asus\AppData\Roaming\Python\Python312\site-packages\mealpy\utils\validator.py", line 54, in check_int
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\Asus\AppData\Local\Temp\ipykernel_14716\1739199214.py", line 444, in optimize
#     raise ValueError(f"'{name}' is an integer {bound}.")
# ValueError: 'n_workers' is an integer and value should be in range: [2, 20].
#     _threading_Thread_run(self)
#   File "C:\Program Files\Python312\Lib\threading.py", line 1010, in run
#   File "C:\Users\Asus\AppData\Roaming\Python\Python312\site-packages\mealpy\optimizer.py", line 224, in solve
#   File "C:\Users\Asus\AppData\Roaming\Python\Python312\site-packages\mealpy\optimizer.py", line 224, in solve
#     self.check_mode_and_workers(mode, n_workers)
#   File "C:\Users\Asus\AppData\Roaming\Python\Python312\site-packages\mealpy\optimizer.py", line 176, in check_mode_and_workers
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\Asus\AppData\Local\Temp\ipykernel_14716\1739199214.py", line 444, in optimize
#     self.check_mode_and_workers(mode, n_workers)
#   File "C:\Users\Asus\AppData\Roaming\Python\Python312\site-packages\mealpy\optimizer.py", line 176, in check_mode_and_workers
#   File "C:\Users\Asus\AppData\Roaming\Python\Python312\site-packages\mealpy\optimizer.py", line 224, in solve
#     self.n_workers = self.validator.check_int("n_workers", n_workers, [2, min(32, os.cpu_count() + 4)])
#                      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Asus\AppData\Roaming\Python\Python312\site-packages\mealpy\utils\validator.py", line 54, in check_int
#     self.check_mode_and_workers(mode, n_workers)
#   File "C:\Users\Asus\AppData\Roaming\Python\Python312\site-packages\mealpy\optimizer.py", line 176, in check_mode_and_workers
#     self.n_workers = self.validator.check_int("n_workers", n_workers, [2, min(32, os.cpu_count() + 4)])
#                      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Asus\AppData\Roaming\Python\Python312\site-packages\mealpy\utils\validator.py", line 54, in check_int
#     raise ValueError(f"'{name}' is an integer {bound}.")
# ValueError: 'n_workers' is an integer and value should be in range: [2, 20].
#   File "C:\Users\Asus\AppData\Roaming\Python\Python312\site-packages\mealpy\optimizer.py", line 224, in solve
#     raise ValueError(f"'{name}' is an integer {bound}.")
# ValueError: 'n_workers' is an integer and value should be in range: [2, 20].
#     self.n_workers = self.validator.check_int("n_workers", n_workers, [2, min(32, os.cpu_count() + 4)])
#                      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Asus\AppData\Roaming\Python\Python312\site-packages\mealpy\utils\validator.py", line 54, in check_int
#     self.check_mode_and_workers(mode, n_workers)
#   File "C:\Users\Asus\AppData\Roaming\Python\Python312\site-packages\mealpy\optimizer.py", line 176, in check_mode_and_workers
#     raise ValueError(f"'{name}' is an integer {bound}.")
# ValueError: 'n_workers' is an integer and value should be in range: [2, 20].
#     self.n_workers = self.validator.check_int("n_workers", n_workers, [2, min(32, os.cpu_count() + 4)])
#                      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Asus\AppData\Roaming\Python\Python312\site-packages\mealpy\utils\validator.py", line 54, in check_int
#     raise ValueError(f"'{name}' is an integer {bound}.")
# ValueError: 'n_workers' is an integer and value should be in range: [2, 20].
# 2025/07/02 11:39:13 AM, INFO, mealpy.human_based.HBO.OriginalHBO: Solving single objective optimization problem.
# 2025/07/02 11:39:13 AM, WARNING, mealpy.human_based.HBO.OriginalHBO: OriginalHBO doesn't support parallelization. The default mode 'single' is activated.
# 2025/07/02 11:39:13 AM, INFO, mealpy.human_based.HBO.OriginalHBO: Solving single objective optimization problem.
# 2025/07/02 11:39:13 AM, INFO, mealpy.human_based.HBO.OriginalHBO: Solving single objective optimization problem.
# Finished EFO1
# An exception occurred
# 2025/07/02 11:39:13 AM, INFO, mealpy.human_based.HBO.OriginalHBO: Solving single objective optimization problem.
# 2025/07/02 11:39:13 AM, INFO, mealpy.human_based.HBO.OriginalHBO: Solving single objective optimization problem.
# 2025/07/02 11:39:14 AM, WARNING, mealpy.human_based.HBO.OriginalHBO: OriginalHBO doesn't support parallelization. The default mode 'single' is activated.
# 2025/07/02 11:39:14 AM, INFO, mealpy.human_based.HBO.OriginalHBO: Solving single objective optimization problem.
# 2025/07/02 11:39:14 AM, INFO, mealpy.human_based.HBO.OriginalHBO: >>>Problem: P, Epoch: 1, Current best: 416.0, Global best: 416.0, Runtime: 0.13852 seconds
# 2025/07/02 11:39:14 AM, WARNING, mealpy.human_based.HBO.OriginalHBO: OriginalHBO doesn't support parallelization. The default mode 'single' is activated.
# 2025/07/02 11:39:14 AM, WARNING, mealpy.human_based.HBO.OriginalHBO: OriginalHBO doesn't support parallelization. The default mode 'single' is activated.
# 2025/07/02 11:39:14 AM, WARNING, mealpy.human_based.HBO.OriginalHBO: OriginalHBO doesn't support parallelization. The default mode 'single' is activated.
# 2025/07/02 11:39:14 AM, WARNING, mealpy.human_based.HBO.OriginalHBO: OriginalHBO doesn't support parallelization. The default mode 'single' is activated.
# 2025/07/02 11:39:14 AM, INFO, mealpy.human_based.HBO.OriginalHBO: >>>Problem: P, Epoch: 2, Current best: 416.0, Global best: 416.0, Runtime: 0.36685 seconds
# 2025/07/02 11:39:15 AM, INFO, mealpy.human_based.HBO.OriginalHBO: >>>Problem: P, Epoch: 3, Current best: 416.0, Global best: 416.0, Runtime: 0.87091 seconds
# 2025/07/02 11:39:15 AM, INFO, mealpy.human_based.HBO.OriginalHBO: >>>Problem: P, Epoch: 1, Current best: 2624.0, Global best: 2624.0, Runtime: 1.18658 seconds
# 2025/07/02 11:39:16 AM, INFO, mealpy.human_based.HBO.OriginalHBO: >>>Problem: P, Epoch: 4, Current best: 416.0, Global best: 416.0, Runtime: 0.82802 seconds
# 2025/07/02 11:39:17 AM, INFO, mealpy.human_based.HBO.OriginalHBO: >>>Problem: P, Epoch: 2, Current best: 2624.0, Global best: 2624.0, Runtime: 0.92755 seconds
# 2025/07/02 11:39:17 AM, INFO, mealpy.human_based.HBO.OriginalHBO: >>>Problem: P, Epoch: 5, Current best: 416.0, Global best: 416.0, Runtime: 1.02692 seconds
# 2025/07/02 11:39:18 AM, INFO, mealpy.human_based.HBO.OriginalHBO: >>>Problem: P, Epoch: 3, Current best: 2592.0, Global best: 2592.0, Runtime: 0.91235 seconds
# 2025/07/02 11:39:18 AM, INFO, mealpy.human_based.HBO.OriginalHBO: >>>Problem: P, Epoch: 4, Current best: 2592.0, Global best: 2592.0, Runtime: 0.53981 seconds
# 2025/07/02 11:39:19 AM, INFO, mealpy.human_based.HBO.OriginalHBO: >>>Problem: P, Epoch: 6, Current best: 400.0, Global best: 400.0, Runtime: 1.05269 seconds
# 2025/07/02 11:39:19 AM, INFO, mealpy.human_based.HBO.OriginalHBO: >>>Problem: P, Epoch: 5, Current best: 2592.0, Global best: 2592.0, Runtime: 0.91167 seconds
# 2025/07/02 11:39:20 AM, INFO, mealpy.human_based.HBO.OriginalHBO: >>>Problem: P, Epoch: 6, Current best: 2592.0, Global best: 2592.0, Runtime: 0.64154 seconds
# 2025/07/02 11:39:20 AM, INFO, mealpy.human_based.HBO.OriginalHBO: >>>Problem: P, Epoch: 7, Current best: 384.0, Global best: 384.0, Runtime: 1.11460 seconds
# 2025/07/02 11:39:21 AM, INFO, mealpy.human_based.HBO.OriginalHBO: >>>Problem: P, Epoch: 7, Current best: 2592.0, Global best: 2592.0, Runtime: 0.63597 seconds
# 2025/07/02 11:39:22 AM, INFO, mealpy.human_based.HBO.OriginalHBO: >>>Problem: P, Epoch: 1, Current best: 5424.0, Global best: 5424.0, Runtime: 2.67315 seconds
# 2025/07/02 11:39:22 AM, INFO, mealpy.human_based.HBO.OriginalHBO: >>>Problem: P, Epoch: 8, Current best: 384.0, Global best: 384.0, Runtime: 1.29735 seconds
# 2025/07/02 11:39:22 AM, INFO, mealpy.human_based.HBO.OriginalHBO: >>>Problem: P, Epoch: 8, Current best: 2592.0, Global best: 2592.0, Runtime: 0.74670 seconds
# 2025/07/02 11:39:23 AM, INFO, mealpy.human_based.HBO.OriginalHBO: >>>Problem: P, Epoch: 9, Current best: 2560.0, Global best: 2560.0, Runtime: 0.66368 seconds
# 2025/07/02 11:39:23 AM, INFO, mealpy.human_based.HBO.OriginalHBO: >>>Problem: P, Epoch: 1, Current best: 8352.0, Global best: 8352.0, Runtime: 3.25110 seconds
# 2025/07/02 11:39:23 AM, INFO, mealpy.human_based.HBO.OriginalHBO: >>>Problem: P, Epoch: 9, Current best: 384.0, Global best: 384.0, Runtime: 1.25912 seconds
# 2025/07/02 11:39:24 AM, INFO, mealpy.human_based.HBO.OriginalHBO: >>>Problem: P, Epoch: 10, Current best: 2560.0, Global best: 2560.0, Runtime: 0.59549 seconds
# 2025/07/02 11:39:24 AM, INFO, mealpy.human_based.HBO.OriginalHBO: >>>Problem: P, Epoch: 1, Current best: 10976.0, Global best: 10976.0, Runtime: 3.60926 seconds
# 2025/07/02 11:39:24 AM, INFO, mealpy.human_based.HBO.OriginalHBO: >>>Problem: P, Epoch: 10, Current best: 384.0, Global best: 384.0, Runtime: 0.93330 seconds
# 2025/07/02 11:39:24 AM, INFO, mealpy.human_based.HBO.OriginalHBO: >>>Problem: P, Epoch: 1, Current best: 14240.0, Global best: 14240.0, Runtime: 4.01910 seconds
# 2025/07/02 11:39:24 AM, INFO, mealpy.human_based.HBO.OriginalHBO: >>>Problem: P, Epoch: 2, Current best: 5424.0, Global best: 5424.0, Runtime: 2.03195 seconds
# 2025/07/02 11:39:24 AM, INFO, mealpy.human_based.HBO.OriginalHBO: >>>Problem: P, Epoch: 11, Current best: 2480.0, Global best: 2480.0, Runtime: 0.64712 seconds
# 2025/07/02 11:39:25 AM, INFO, mealpy.human_based.HBO.OriginalHBO: >>>Problem: P, Epoch: 11, Current best: 384.0, Global best: 384.0, Runtime: 0.47686 seconds
# 2025/07/02 11:39:26 AM, INFO, mealpy.human_based.HBO.OriginalHBO: >>>Problem: P, Epoch: 12, Current best: 2336.0, Global best: 2336.0, Runtime: 0.80806 seconds
# 2025/07/02 11:39:27 AM, INFO, mealpy.human_based.HBO.OriginalHBO: >>>Problem: P, Epoch: 2, Current best: 8336.0, Global best: 8336.0, Runtime: 2.63794 seconds
# 2025/07/02 11:39:27 AM, INFO, mealpy.human_based.HBO.OriginalHBO: >>>Problem: P, Epoch: 12, Current best: 384.0, Global best: 384.0, Runtime: 1.21300 seconds
# 2025/07/02 11:39:27 AM, INFO, mealpy.human_based.HBO.OriginalHBO: >>>Problem: P, Epoch: 13, Current best: 2304.0, Global best: 2304.0, Runtime: 0.50655 seconds
# 2025/07/02 11:39:28 AM, INFO, mealpy.human_based.HBO.OriginalHBO: >>>Problem: P, Epoch: 3, Current best: 5376.0, Global best: 5376.0, Runtime: 2.08209 seconds
# 2025/07/02 11:39:28 AM, INFO, mealpy.human_based.HBO.OriginalHBO: >>>Problem: P, Epoch: 13, Current best: 384.0, Global best: 384.0, Runtime: 0.85513 seconds
# 2025/07/02 11:39:28 AM, INFO, mealpy.human_based.HBO.OriginalHBO: >>>Problem: P, Epoch: 14, Current best: 2304.0, Global best: 2304.0, Runtime: 0.58592 seconds
# 2025/07/02 11:39:28 AM, INFO, mealpy.human_based.HBO.OriginalHBO: >>>Problem: P, Epoch: 2, Current best: 10976.0, Global best: 10976.0, Runtime: 3.30051 seconds
# 2025/07/02 11:39:29 AM, INFO, mealpy.human_based.HBO.OriginalHBO: >>>Problem: P, Epoch: 15, Current best: 2304.0, Global best: 2304.0, Runtime: 0.48510 seconds
# 2025/07/02 11:39:29 AM, INFO, mealpy.human_based.HBO.OriginalHBO: >>>Problem: P, Epoch: 14, Current best: 384.0, Global best: 384.0, Runtime: 0.83873 seconds
# 2025/07/02 11:39:29 AM, INFO, mealpy.human_based.HBO.OriginalHBO: >>>Problem: P, Epoch: 2, Current best: 14240.0, Global best: 14240.0, Runtime: 3.87355 seconds
# 2025/07/02 11:39:29 AM, INFO, mealpy.human_based.HBO.OriginalHBO: >>>Problem: P, Epoch: 16, Current best: 2304.0, Global best: 2304.0, Runtime: 0.58621 seconds
# 2025/07/02 11:39:29 AM, INFO, mealpy.human_based.HBO.OriginalHBO: >>>Problem: P, Epoch: 3, Current best: 8288.0, Global best: 8288.0, Runtime: 2.24561 seconds
# 2025/07/02 11:39:30 AM, INFO, mealpy.human_based.HBO.OriginalHBO: >>>Problem: P, Epoch: 4, Current best: 5344.0, Global best: 5344.0, Runtime: 1.55122 seconds
# 2025/07/02 11:39:30 AM, INFO, mealpy.human_based.HBO.OriginalHBO: >>>Problem: P, Epoch: 15, Current best: 384.0, Global best: 384.0, Runtime: 0.90150 seconds
# 2025/07/02 11:39:30 AM, INFO, mealpy.human_based.HBO.OriginalHBO: >>>Problem: P, Epoch: 17, Current best: 2304.0, Global best: 2304.0, Runtime: 0.56342 seconds
# 2025/07/02 11:39:31 AM, INFO, mealpy.human_based.HBO.OriginalHBO: >>>Problem: P, Epoch: 18, Current best: 2304.0, Global best: 2304.0, Runtime: 0.50068 seconds
# 2025/07/02 11:39:31 AM, INFO, mealpy.human_based.HBO.OriginalHBO: >>>Problem: P, Epoch: 16, Current best: 384.0, Global best: 384.0, Runtime: 1.08809 seconds
# 2025/07/02 11:39:31 AM, INFO, mealpy.human_based.HBO.OriginalHBO: >>>Problem: P, Epoch: 3, Current best: 10976.0, Global best: 10976.0, Runtime: 2.77747 seconds
# 2025/07/02 11:39:32 AM, INFO, mealpy.human_based.HBO.OriginalHBO: >>>Problem: P, Epoch: 19, Current best: 2304.0, Global best: 2304.0, Runtime: 0.65862 seconds
# 2025/07/02 11:39:32 AM, INFO, mealpy.human_based.HBO.OriginalHBO: >>>Problem: P, Epoch: 5, Current best: 5344.0, Global best: 5344.0, Runtime: 1.87350 seconds
# 2025/07/02 11:39:32 AM, INFO, mealpy.human_based.HBO.OriginalHBO: >>>Problem: P, Epoch: 17, Current best: 368.0, Global best: 368.0, Runtime: 0.66100 seconds
# 2025/07/02 11:39:33 AM, INFO, mealpy.human_based.HBO.OriginalHBO: >>>Problem: P, Epoch: 20, Current best: 2304.0, Global best: 2304.0, Runtime: 0.80565 seconds
# 2025/07/02 11:39:33 AM, INFO, mealpy.human_based.HBO.OriginalHBO: >>>Problem: P, Epoch: 4, Current best: 8288.0, Global best: 8288.0, Runtime: 2.83605 seconds
# 2025/07/02 11:39:33 AM, INFO, mealpy.human_based.HBO.OriginalHBO: >>>Problem: P, Epoch: 18, Current best: 368.0, Global best: 368.0, Runtime: 0.67714 seconds
# 2025/07/02 11:39:33 AM, INFO, mealpy.human_based.HBO.OriginalHBO: >>>Problem: P, Epoch: 3, Current best: 14240.0, Global best: 14240.0, Runtime: 3.61908 seconds
# 2025/07/02 11:39:34 AM, INFO, mealpy.human_based.HBO.OriginalHBO: >>>Problem: P, Epoch: 21, Current best: 2304.0, Global best: 2304.0, Runtime: 0.84244 seconds
# 2025/07/02 11:39:35 AM, INFO, mealpy.human_based.HBO.OriginalHBO: >>>Problem: P, Epoch: 19, Current best: 368.0, Global best: 368.0, Runtime: 1.06579 seconds
# 2025/07/02 11:39:35 AM, INFO, mealpy.human_based.HBO.OriginalHBO: >>>Problem: P, Epoch: 22, Current best: 2304.0, Global best: 2304.0, Runtime: 0.86073 seconds
# 2025/07/02 11:39:35 AM, INFO, mealpy.human_based.HBO.OriginalHBO: >>>Problem: P, Epoch: 6, Current best: 5344.0, Global best: 5344.0, Runtime: 2.65270 seconds
# 2025/07/02 11:39:36 AM, INFO, mealpy.human_based.HBO.OriginalHBO: >>>Problem: P, Epoch: 20, Current best: 352.0, Global best: 352.0, Runtime: 0.93435 seconds
# 2025/07/02 11:39:36 AM, INFO, mealpy.human_based.HBO.OriginalHBO: >>>Problem: P, Epoch: 23, Current best: 2304.0, Global best: 2304.0, Runtime: 0.79804 seconds
# 2025/07/02 11:39:36 AM, INFO, mealpy.human_based.HBO.OriginalHBO: >>>Problem: P, Epoch: 4, Current best: 10976.0, Global best: 10976.0, Runtime: 3.95817 seconds
# 2025/07/02 11:39:36 AM, INFO, mealpy.human_based.HBO.OriginalHBO: >>>Problem: P, Epoch: 5, Current best: 8288.0, Global best: 8288.0, Runtime: 3.10818 seconds
# 2025/07/02 11:39:37 AM, INFO, mealpy.human_based.HBO.OriginalHBO: >>>Problem: P, Epoch: 21, Current best: 352.0, Global best: 352.0, Runtime: 0.62149 seconds
# 2025/07/02 11:39:37 AM, INFO, mealpy.human_based.HBO.OriginalHBO: >>>Problem: P, Epoch: 24, Current best: 2304.0, Global best: 2304.0, Runtime: 0.77819 seconds
# 2025/07/02 11:39:38 AM, INFO, mealpy.human_based.HBO.OriginalHBO: >>>Problem: P, Epoch: 7, Current best: 5344.0, Global best: 5344.0, Runtime: 1.65096 seconds
# 2025/07/02 11:39:38 AM, INFO, mealpy.human_based.HBO.OriginalHBO: >>>Problem: P, Epoch: 22, Current best: 352.0, Global best: 352.0, Runtime: 0.68426 seconds
# 2025/07/02 11:39:38 AM, INFO, mealpy.human_based.HBO.OriginalHBO: >>>Problem: P, Epoch: 4, Current best: 14240.0, Global best: 14240.0, Runtime: 4.13650 seconds
# 2025/07/02 11:39:38 AM, INFO, mealpy.human_based.HBO.OriginalHBO: >>>Problem: P, Epoch: 25, Current best: 2304.0, Global best: 2304.0, Runtime: 0.69844 seconds
# 2025/07/02 11:39:39 AM, INFO, mealpy.human_based.HBO.OriginalHBO: >>>Problem: P, Epoch: 23, Current best: 352.0, Global best: 352.0, Runtime: 1.03936 seconds
# 2025/07/02 11:39:40 AM, INFO, mealpy.human_based.HBO.OriginalHBO: >>>Problem: P, Epoch: 26, Current best: 2304.0, Global best: 2304.0, Runtime: 0.80285 seconds
# 2025/07/02 11:39:40 AM, INFO, mealpy.human_based.HBO.OriginalHBO: >>>Problem: P, Epoch: 5, Current best: 10976.0, Global best: 10976.0, Runtime: 2.99261 seconds
# 2025/07/02 11:39:40 AM, INFO, mealpy.human_based.HBO.OriginalHBO: >>>Problem: P, Epoch: 6, Current best: 8288.0, Global best: 8288.0, Runtime: 2.82443 seconds
# 2025/07/02 11:39:40 AM, INFO, mealpy.human_based.HBO.OriginalHBO: >>>Problem: P, Epoch: 27, Current best: 2304.0, Global best: 2304.0, Runtime: 0.49878 seconds
# 2025/07/02 11:39:40 AM, INFO, mealpy.human_based.HBO.OriginalHBO: >>>Problem: P, Epoch: 24, Current best: 352.0, Global best: 352.0, Runtime: 0.73128 seconds
# 2025/07/02 11:39:40 AM, INFO, mealpy.human_based.HBO.OriginalHBO: >>>Problem: P, Epoch: 8, Current best: 5312.0, Global best: 5312.0, Runtime: 2.27787 seconds
# 2025/07/02 11:39:42 AM, INFO, mealpy.human_based.HBO.OriginalHBO: >>>Problem: P, Epoch: 28, Current best: 2304.0, Global best: 2304.0, Runtime: 1.09430 seconds
# 2025/07/02 11:39:42 AM, INFO, mealpy.human_based.HBO.OriginalHBO: >>>Problem: P, Epoch: 25, Current best: 336.0, Global best: 336.0, Runtime: 1.06444 seconds
# 2025/07/02 11:39:42 AM, INFO, mealpy.human_based.HBO.OriginalHBO: >>>Problem: P, Epoch: 5, Current best: 14240.0, Global best: 14240.0, Runtime: 3.43674 seconds
# 2025/07/02 11:39:43 AM, INFO, mealpy.human_based.HBO.OriginalHBO: >>>Problem: P, Epoch: 29, Current best: 2304.0, Global best: 2304.0, Runtime: 0.63054 seconds
# 2025/07/02 11:39:43 AM, INFO, mealpy.human_based.HBO.OriginalHBO: >>>Problem: P, Epoch: 26, Current best: 336.0, Global best: 336.0, Runtime: 0.80154 seconds
# ...
# 2025/07/02 11:45:16 AM, INFO, mealpy.human_based.HBO.OriginalHBO: >>>Problem: P, Epoch: 85, Current best: 7904.0, Global best: 7904.0, Runtime: 2.64575 seconds
# 2025/07/02 11:45:16 AM, INFO, mealpy.human_based.HBO.OriginalHBO: >>>Problem: P, Epoch: 64, Current best: 13680.0, Global best: 13680.0, Runtime: 3.41002 seconds
# 2025/07/02 11:45:16 AM, INFO, mealpy.human_based.HBO.OriginalHBO: >>>Problem: P, Epoch: 72, Current best: 10480.0, Global best: 10480.0, Runtime: 3.36210 seconds
# 2025/07/02 11:45:18 AM, INFO, mealpy.human_based.HBO.OriginalHBO: >>>Problem: P, Epoch: 86, Current best: 7904.0, Global best: 7904.0, Runtime: 2.33642 seconds
# 2025/07/02 11:45:19 AM, INFO, mealpy.human_based.HBO.OriginalHBO: >>>Problem: P, Epoch: 73, Current best: 10480.0, Global best: 10480.0, Runtime: 3.41199 seconds
# 2025/07/02 11:45:19 AM, INFO, mealpy.human_based.HBO.OriginalHBO: >>>Problem: P, Epoch: 65, Current best: 13680.0, Global best: 13680.0, Runtime: 3.66028 seconds
# 2025/07/02 11:45:21 AM, INFO, mealpy.human_based.HBO.OriginalHBO: >>>Problem: P, Epoch: 87, Current best: 7904.0, Global best: 7904.0, Runtime: 2.15272 seconds
# 2025/07/02 11:45:23 AM, INFO, mealpy.human_based.HBO.OriginalHBO: >>>Problem: P, Epoch: 74, Current best: 10480.0, Global best: 10480.0, Runtime: 2.86335 seconds
# 2025/07/02 11:45:23 AM, INFO, mealpy.human_based.HBO.OriginalHBO: >>>Problem: P, Epoch: 66, Current best: 13680.0, Global best: 13680.0, Runtime: 3.00467 seconds
# 2025/07/02 11:45:23 AM, INFO, mealpy.human_based.HBO.OriginalHBO: >>>Problem: P, Epoch: 88, Current best: 7904.0, Global best: 7904.0, Runtime: 2.37737 seconds
# 2025/07/02 11:45:26 AM, INFO, mealpy.human_based.HBO.OriginalHBO: >>>Problem: P, Epoch: 75, Current best: 10480.0, Global best: 10480.0, Runtime: 3.18081 seconds
# 2025/07/02 11:45:26 AM, INFO, mealpy.human_based.HBO.OriginalHBO: >>>Problem: P, Epoch: 89, Current best: 7904.0, Global best: 7904.0, Runtime: 2.63809 seconds
# 2025/07/02 11:45:27 AM, INFO, mealpy.human_based.HBO.OriginalHBO: >>>Problem: P, Epoch: 67, Current best: 13680.0, Global best: 13680.0, Runtime: 3.29743 seconds
# 2025/07/02 11:45:29 AM, INFO, mealpy.human_based.HBO.OriginalHBO: >>>Problem: P, Epoch: 90, Current best: 7904.0, Global best: 7904.0, Runtime: 2.26989 seconds
# 2025/07/02 11:45:29 AM, INFO, mealpy.human_based.HBO.OriginalHBO: >>>Problem: P, Epoch: 76, Current best: 10480.0, Global best: 10480.0, Runtime: 2.48318 seconds
# 2025/07/02 11:45:30 AM, INFO, mealpy.human_based.HBO.OriginalHBO: >>>Problem: P, Epoch: 68, Current best: 13680.0, Global best: 13680.0, Runtime: 2.88980 seconds
# 2025/07/02 11:45:31 AM, INFO, mealpy.human_based.HBO.OriginalHBO: >>>Problem: P, Epoch: 91, Current best: 7904.0, Global best: 7904.0, Runtime: 2.03966 seconds
# 2025/07/02 11:45:32 AM, INFO, mealpy.human_based.HBO.OriginalHBO: >>>Problem: P, Epoch: 77, Current best: 10480.0, Global best: 10480.0, Runtime: 2.40847 seconds
# 2025/07/02 11:45:34 AM, INFO, mealpy.human_based.HBO.OriginalHBO: >>>Problem: P, Epoch: 92, Current best: 7904.0, Global best: 7904.0, Runtime: 2.65345 seconds
# 2025/07/02 11:45:34 AM, INFO, mealpy.human_based.HBO.OriginalHBO: >>>Problem: P, Epoch: 69, Current best: 13680.0, Global best: 13680.0, Runtime: 3.21364 seconds
# 2025/07/02 11:45:35 AM, INFO, mealpy.human_based.HBO.OriginalHBO: >>>Problem: P, Epoch: 78, Current best: 10480.0, Global best: 10480.0, Runtime: 2.63308 seconds
# 2025/07/02 11:45:36 AM, INFO, mealpy.human_based.HBO.OriginalHBO: >>>Problem: P, Epoch: 93, Current best: 7904.0, Global best: 7904.0, Runtime: 2.14164 seconds
# 2025/07/02 11:45:37 AM, INFO, mealpy.human_based.HBO.OriginalHBO: >>>Problem: P, Epoch: 70, Current best: 13680.0, Global best: 13680.0, Runtime: 3.06426 seconds
# 2025/07/02 11:45:38 AM, INFO, mealpy.human_based.HBO.OriginalHBO: >>>Problem: P, Epoch: 79, Current best: 10480.0, Global best: 10480.0, Runtime: 3.00530 seconds
# 2025/07/02 11:45:39 AM, INFO, mealpy.human_based.HBO.OriginalHBO: >>>Problem: P, Epoch: 94, Current best: 7904.0, Global best: 7904.0, Runtime: 1.86313 seconds
# 2025/07/02 11:45:41 AM, INFO, mealpy.human_based.HBO.OriginalHBO: >>>Problem: P, Epoch: 71, Current best: 13680.0, Global best: 13680.0, Runtime: 3.22142 seconds
# 2025/07/02 11:45:42 AM, INFO, mealpy.human_based.HBO.OriginalHBO: >>>Problem: P, Epoch: 95, Current best: 7904.0, Global best: 7904.0, Runtime: 2.68870 seconds
# 2025/07/02 11:45:42 AM, INFO, mealpy.human_based.HBO.OriginalHBO: >>>Problem: P, Epoch: 80, Current best: 10480.0, Global best: 10480.0, Runtime: 3.25135 seconds
# 2025/07/02 11:45:45 AM, INFO, mealpy.human_based.HBO.OriginalHBO: >>>Problem: P, Epoch: 96, Current best: 7904.0, Global best: 7904.0, Runtime: 2.23353 seconds
# 2025/07/02 11:45:45 AM, INFO, mealpy.human_based.HBO.OriginalHBO: >>>Problem: P, Epoch: 72, Current best: 13680.0, Global best: 13680.0, Runtime: 3.17467 seconds
# 2025/07/02 11:45:45 AM, INFO, mealpy.human_based.HBO.OriginalHBO: >>>Problem: P, Epoch: 81, Current best: 10480.0, Global best: 10480.0, Runtime: 2.59933 seconds
# 2025/07/02 11:45:46 AM, INFO, mealpy.human_based.HBO.OriginalHBO: >>>Problem: P, Epoch: 97, Current best: 7904.0, Global best: 7904.0, Runtime: 1.63099 seconds
# 2025/07/02 11:45:48 AM, INFO, mealpy.human_based.HBO.OriginalHBO: >>>Problem: P, Epoch: 73, Current best: 13680.0, Global best: 13680.0, Runtime: 3.15710 seconds
# 2025/07/02 11:45:49 AM, INFO, mealpy.human_based.HBO.OriginalHBO: >>>Problem: P, Epoch: 82, Current best: 10480.0, Global best: 10480.0, Runtime: 3.19050 seconds
# 2025/07/02 11:45:49 AM, INFO, mealpy.human_based.HBO.OriginalHBO: >>>Problem: P, Epoch: 98, Current best: 7904.0, Global best: 7904.0, Runtime: 2.19279 seconds
# 2025/07/02 11:45:52 AM, INFO, mealpy.human_based.HBO.OriginalHBO: >>>Problem: P, Epoch: 99, Current best: 7904.0, Global best: 7904.0, Runtime: 2.68650 seconds
# 2025/07/02 11:45:52 AM, INFO, mealpy.human_based.HBO.OriginalHBO: >>>Problem: P, Epoch: 83, Current best: 10480.0, Global best: 10480.0, Runtime: 3.05681 seconds
# 2025/07/02 11:45:52 AM, INFO, mealpy.human_based.HBO.OriginalHBO: >>>Problem: P, Epoch: 74, Current best: 13680.0, Global best: 13680.0, Runtime: 3.26857 seconds
# 2025/07/02 11:45:55 AM, INFO, mealpy.human_based.HBO.OriginalHBO: >>>Problem: P, Epoch: 100, Current best: 7904.0, Global best: 7904.0, Runtime: 2.50102 seconds
# Exception in thread Thread-92 (optimize):
# Traceback (most recent call last):
#   File "C:\Program Files\Python312\Lib\threading.py", line 1073, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Asus\AppData\Roaming\Python\Python312\site-packages\ipykernel\ipkernel.py", line 766, in run_closure
#     _threading_Thread_run(self)
#   File "C:\Program Files\Python312\Lib\threading.py", line 1010, in run
# 2025/07/02 11:45:55 AM, INFO, mealpy.human_based.HBO.OriginalHBO: >>>Problem: P, Epoch: 84, Current best: 10480.0, Global best: 10480.0, Runtime: 2.93532 seconds
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\Asus\AppData\Local\Temp\ipykernel_14716\1739199214.py", line 448, in optimize
# Solution: [  2.47628169   3.00503917   2.97520789 ...   1.73668146 -16.22408947
#  -47.57272745], Fitness: [  2.47628169   3.00503917   2.97520789 ...   1.73668146 -16.22408947
#  -47.57272745]
#   File "C:\Users\Asus\AppData\Local\Temp\ipykernel_14716\2660593827.py", line 9, in Fun1
# IndexError: list index out of range
# 2025/07/02 11:45:55 AM, INFO, mealpy.human_based.HBO.OriginalHBO: >>>Problem: P, Epoch: 75, Current best: 13680.0, Global best: 13680.0, Runtime: 2.96787 seconds
# 2025/07/02 11:45:57 AM, INFO, mealpy.human_based.HBO.OriginalHBO: >>>Problem: P, Epoch: 85, Current best: 10480.0, Global best: 10480.0, Runtime: 1.76694 seconds
# 2025/07/02 11:45:58 AM, INFO, mealpy.human_based.HBO.OriginalHBO: >>>Problem: P, Epoch: 76, Current best: 13680.0, Global best: 13680.0, Runtime: 2.18285 seconds
# 2025/07/02 11:45:59 AM, INFO, mealpy.human_based.HBO.OriginalHBO: >>>Problem: P, Epoch: 86, Current best: 10480.0, Global best: 10480.0, Runtime: 1.62617 seconds
# 2025/07/02 11:46:00 AM, INFO, mealpy.human_based.HBO.OriginalHBO: >>>Problem: P, Epoch: 77, Current best: 13680.0, Global best: 13680.0, Runtime: 1.96585 seconds
# 2025/07/02 11:46:01 AM, INFO, mealpy.human_based.HBO.OriginalHBO: >>>Problem: P, Epoch: 87, Current best: 10480.0, Global best: 10480.0, Runtime: 1.72526 seconds
# 2025/07/02 11:46:02 AM, INFO, mealpy.human_based.HBO.OriginalHBO: >>>Problem: P, Epoch: 78, Current best: 13680.0, Global best: 13680.0, Runtime: 1.98643 seconds
# 2025/07/02 11:46:03 AM, INFO, mealpy.human_based.HBO.OriginalHBO: >>>Problem: P, Epoch: 88, Current best: 10480.0, Global best: 10480.0, Runtime: 2.22530 seconds
# 2025/07/02 11:46:05 AM, INFO, mealpy.human_based.HBO.OriginalHBO: >>>Problem: P, Epoch: 79, Current best: 13680.0, Global best: 13680.0, Runtime: 2.36102 seconds
# 2025/07/02 11:46:05 AM, INFO, mealpy.human_based.HBO.OriginalHBO: >>>Problem: P, Epoch: 89, Current best: 10480.0, Global best: 10480.0, Runtime: 2.04565 seconds
# 2025/07/02 11:46:07 AM, INFO, mealpy.human_based.HBO.OriginalHBO: >>>Problem: P, Epoch: 90, Current best: 10480.0, Global best: 10480.0, Runtime: 1.89723 seconds
# 2025/07/02 11:46:07 AM, INFO, mealpy.human_based.HBO.OriginalHBO: >>>Problem: P, Epoch: 80, Current best: 13680.0, Global best: 13680.0, Runtime: 2.42048 seconds
# 2025/07/02 11:46:10 AM, INFO, mealpy.human_based.HBO.OriginalHBO: >>>Problem: P, Epoch: 91, Current best: 10480.0, Global best: 10480.0, Runtime: 2.07627 seconds
# 2025/07/02 11:46:10 AM, INFO, mealpy.human_based.HBO.OriginalHBO: >>>Problem: P, Epoch: 81, Current best: 13680.0, Global best: 13680.0, Runtime: 2.35476 seconds
# 2025/07/02 11:46:12 AM, INFO, mealpy.human_based.HBO.OriginalHBO: >>>Problem: P, Epoch: 92, Current best: 10480.0, Global best: 10480.0, Runtime: 1.86105 seconds
# 2025/07/02 11:46:12 AM, INFO, mealpy.human_based.HBO.OriginalHBO: >>>Problem: P, Epoch: 82, Current best: 13680.0, Global best: 13680.0, Runtime: 2.32694 seconds
# 2025/07/02 11:46:14 AM, INFO, mealpy.human_based.HBO.OriginalHBO: >>>Problem: P, Epoch: 93, Current best: 10480.0, Global best: 10480.0, Runtime: 2.15595 seconds
# 2025/07/02 11:46:15 AM, INFO, mealpy.human_based.HBO.OriginalHBO: >>>Problem: P, Epoch: 83, Current best: 13680.0, Global best: 13680.0, Runtime: 2.34531 seconds
# 2025/07/02 11:46:16 AM, INFO, mealpy.human_based.HBO.OriginalHBO: >>>Problem: P, Epoch: 94, Current best: 10480.0, Global best: 10480.0, Runtime: 1.89823 seconds
# 2025/07/02 11:46:18 AM, INFO, mealpy.human_based.HBO.OriginalHBO: >>>Problem: P, Epoch: 84, Current best: 13680.0, Global best: 13680.0, Runtime: 2.65044 seconds
# 2025/07/02 11:46:19 AM, INFO, mealpy.human_based.HBO.OriginalHBO: >>>Problem: P, Epoch: 95, Current best: 10480.0, Global best: 10480.0, Runtime: 2.40443 seconds
# 2025/07/02 11:46:20 AM, INFO, mealpy.human_based.HBO.OriginalHBO: >>>Problem: P, Epoch: 85, Current best: 13680.0, Global best: 13680.0, Runtime: 2.44103 seconds
# 2025/07/02 11:46:21 AM, INFO, mealpy.human_based.HBO.OriginalHBO: >>>Problem: P, Epoch: 96, Current best: 10480.0, Global best: 10480.0, Runtime: 1.85232 seconds
# 2025/07/02 11:46:23 AM, INFO, mealpy.human_based.HBO.OriginalHBO: >>>Problem: P, Epoch: 86, Current best: 13680.0, Global best: 13680.0, Runtime: 2.55802 seconds
# 2025/07/02 11:46:23 AM, INFO, mealpy.human_based.HBO.OriginalHBO: >>>Problem: P, Epoch: 97, Current best: 10480.0, Global best: 10480.0, Runtime: 2.19929 seconds
# 2025/07/02 11:46:26 AM, INFO, mealpy.human_based.HBO.OriginalHBO: >>>Problem: P, Epoch: 98, Current best: 10480.0, Global best: 10480.0, Runtime: 2.07333 seconds
# 2025/07/02 11:46:26 AM, INFO, mealpy.human_based.HBO.OriginalHBO: >>>Problem: P, Epoch: 87, Current best: 13680.0, Global best: 13680.0, Runtime: 2.28122 seconds
# 2025/07/02 11:46:28 AM, INFO, mealpy.human_based.HBO.OriginalHBO: >>>Problem: P, Epoch: 99, Current best: 10480.0, Global best: 10480.0, Runtime: 2.28460 seconds
# 2025/07/02 11:46:28 AM, INFO, mealpy.human_based.HBO.OriginalHBO: >>>Problem: P, Epoch: 88, Current best: 13680.0, Global best: 13680.0, Runtime: 2.45992 seconds
# 2025/07/02 11:46:30 AM, INFO, mealpy.human_based.HBO.OriginalHBO: >>>Problem: P, Epoch: 100, Current best: 10480.0, Global best: 10480.0, Runtime: 1.88768 seconds
# Exception in thread Thread-93 (optimize):
# Traceback (most recent call last):
#   File "C:\Program Files\Python312\Lib\threading.py", line 1073, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Asus\AppData\Roaming\Python\Python312\site-packages\ipykernel\ipkernel.py", line 766, in run_closure
# Solution: [  77.54953039    5.71034007 -113.69723132 ...    3.25243985    2.93436339
#     0.78872503], Fitness: [  77.54953039    5.71034007 -113.69723132 ...    3.25243985    2.93436339
#     0.78872503]
#     _threading_Thread_run(self)
#   File "C:\Program Files\Python312\Lib\threading.py", line 1010, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\Asus\AppData\Local\Temp\ipykernel_14716\1739199214.py", line 448, in optimize
#   File "C:\Users\Asus\AppData\Local\Temp\ipykernel_14716\2660593827.py", line 9, in Fun1
# IndexError: list index out of range
# 2025/07/02 11:46:30 AM, INFO, mealpy.human_based.HBO.OriginalHBO: >>>Problem: P, Epoch: 89, Current best: 13680.0, Global best: 13680.0, Runtime: 1.99921 seconds
# 2025/07/02 11:46:32 AM, INFO, mealpy.human_based.HBO.OriginalHBO: >>>Problem: P, Epoch: 90, Current best: 13680.0, Global best: 13680.0, Runtime: 1.20280 seconds
# 2025/07/02 11:46:33 AM, INFO, mealpy.human_based.HBO.OriginalHBO: >>>Problem: P, Epoch: 91, Current best: 13680.0, Global best: 13680.0, Runtime: 1.28991 seconds
# 2025/07/02 11:46:34 AM, INFO, mealpy.human_based.HBO.OriginalHBO: >>>Problem: P, Epoch: 92, Current best: 13680.0, Global best: 13680.0, Runtime: 1.08602 seconds
# 2025/07/02 11:46:35 AM, INFO, mealpy.human_based.HBO.OriginalHBO: >>>Problem: P, Epoch: 93, Current best: 13680.0, Global best: 13680.0, Runtime: 1.15522 seconds
# 2025/07/02 11:46:36 AM, INFO, mealpy.human_based.HBO.OriginalHBO: >>>Problem: P, Epoch: 94, Current best: 13680.0, Global best: 13680.0, Runtime: 1.18760 seconds
# 2025/07/02 11:46:38 AM, INFO, mealpy.human_based.HBO.OriginalHBO: >>>Problem: P, Epoch: 95, Current best: 13680.0, Global best: 13680.0, Runtime: 1.30564 seconds
# 2025/07/02 11:46:39 AM, INFO, mealpy.human_based.HBO.OriginalHBO: >>>Problem: P, Epoch: 96, Current best: 13680.0, Global best: 13680.0, Runtime: 1.47484 seconds
# 2025/07/02 11:46:41 AM, INFO, mealpy.human_based.HBO.OriginalHBO: >>>Problem: P, Epoch: 97, Current best: 13680.0, Global best: 13680.0, Runtime: 1.41154 seconds
# 2025/07/02 11:46:42 AM, INFO, mealpy.human_based.HBO.OriginalHBO: >>>Problem: P, Epoch: 98, Current best: 13680.0, Global best: 13680.0, Runtime: 1.62703 seconds
# 2025/07/02 11:46:43 AM, INFO, mealpy.human_based.HBO.OriginalHBO: >>>Problem: P, Epoch: 99, Current best: 13680.0, Global best: 13680.0, Runtime: 1.29069 seconds
# 2025/07/02 11:46:45 AM, INFO, mealpy.human_based.HBO.OriginalHBO: >>>Problem: P, Epoch: 100, Current best: 13680.0, Global best: 13680.0, Runtime: 1.16888 seconds
# Exception in thread Thread-94 (optimize):
# Traceback (most recent call last):
#   File "C:\Program Files\Python312\Lib\threading.py", line 1073, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Asus\AppData\Roaming\Python\Python312\site-packages\ipykernel\ipkernel.py", line 766, in run_closure
#     _threading_Thread_run(self)
#   File "C:\Program Files\Python312\Lib\threading.py", line 1010, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\Asus\AppData\Local\Temp\ipykernel_14716\1739199214.py", line 448, in optimize
#   File "C:\Users\Asus\AppData\Local\Temp\ipykernel_14716\2660593827.py", line 9, in Fun1
# IndexError: list index out of range
# Solution: [3.00199834 2.92272319 2.99695283 ... 1.99312814 9.84719658 1.99792094], Fitness: [3.00199834 2.92272319 2.99695283 ... 1.99312814 9.84719658 1.99792094]
# Finished HBO
# An exception occurred
